# %% [markdown]
# **Files and Exception Handling Assignment**<br>
# **Course: Data Science with Gen AI (May 2025)**<br>
# **Anoop Verma (anoopmuz@gmail.com**
#
# Q(1) What is the difference between interpreted and compiled languages?
#
# **Ans:-**
# Compilers and Interpreters - both are softwares which are classified as Language Translators and they both translate the computer program written in any high level language to machine-understandable language.
#
# The main difference between these two are as follows:
#
# ** Compilers**
# - The source code is converted into machine code (executable binary) in one go before execution by a compiler.
# - Creates a separate compiled binary file that contains the machine understandable code in it which is directly executed on the CPU.
# - Generally faster because the code is optimized before execution.
# - Harder to debug because errors are checked only after compilation.
# - Compiled binaries are platform-dependent (must be recompiled or linked for different OS/CPU architectures).
# - Once the compiled binary file is created, no need of source code for execution.
# - Examples: C, C++, COBOL, Pascal, Go, Rust, Swift.
#
# **Interpreters**
# - The source code is translated line-by-line and executed by an interpreter and then the next line is translated and executed and so on.
# - No separate compilation step; the interpreter reads and executes code on the fly.
# - Slower because each line is translated during execution.
# - Easier since errors are reported immediately.
# - Source code has to be present during each execution of the program, so more memory is required.
# - More portable—code runs anywhere the interpreter is available.
# - Examples: Python, BASIC, JavaScript (in browsers), Ruby, PHP.
#
# Q(2) What is exception handling in Python?
#
# **Ans:-**
# Exception handling in Python is a mechanism to manage runtime errors (exceptions), preventing the program from crashing unexpectedly. It allows us to detect, handle, and recover from errors in a controlled way.
#
# *Exception* An event that disrupts the normal flow of a program (e.g., division by zero, file not found).
# *Try-Except Block* Catches and handles exceptions.
# *Else Block* Executes if no exception occurs.
# *Finally Block* Always executes, regardless of exceptions.
# *Raise* Manually trigger an exception.
#
# **Common Exceptions are:**
# - ZeroDivisionError	= Division/modulo by zero
# - FileNotFoundError	= File does not exist
# - IndexError = List index out of range
# - KeyError = Dictionary key not found
# - ValueError = Invalid value (e.g., int("abc"))
# - TypeError =	Operation on wrong data type
# - NameError	= Variable not defined
#
# Q(3) What is the purpose of the finally block in exception handling?
#
# **Ans:-**
# The finally block in Python is used to define code that must execute regardless of whether an exception occurs or not. It ensures cleanup or finalization tasks (like closing files, releasing resources, or logging) are always performed.
#
# - Always Executes - Runs whether the try block succeeds, raises an exception, or even if a return statement is encountered.
# - Cleanup Operations -Ideal for releasing resources (files, network connections, locks) to prevent memory leaks.
# - Overrides return in try or except - If finally contains a return, it overrides any previous return statements.
#
# Q(4) What is logging in Python?
#
# **Ans:-**
# Logging is a built-in Python module (logging) used to track events that occur during software execution. It is essential for debugging, monitoring application behavior, and diagnosing issues in production environments. Unlike print() statements (which are temporary and messy), logging provides a structured, configurable, and persistent way to record events.
#
# Q(5) What is the significance of the __del__ method in Python?
#
# **Ans:-**
# The __del__ method is a destructor in Python, automatically called when an object is about to be destroyed (e.g., when it is garbage-collected).
#
# - Purpose - Used for cleanup tasks (e.g., closing files, releasing network connections). Not guaranteed to run immediately when an object goes out of scope (depends on garbage collection).
# - When __del__ is Called - When the object’s reference count drops to zero.
# When the garbage collector reclaims the object (if cyclic references exist).
# During program termination (but not always, especially if the interpreter exits abruptly).
#
# Q(6) What is the difference between import and from ... import in Python?
#
# **Ans:-**
# Both import and from ... import are used to include external modules or functions in your Python code, but they differ in how they load and reference the imported content.
#
# - import Statement=
# Imports an entire module, and you must use the module name as a prefix to access its contents.
#
# Syntax: import module_name
#
# - from ... import Statement =
# Imports specific objects (functions, classes, variables) directly into the current namespace, so you can use them without the module prefix.
#
# Syntax: from module_name import function_name
#
# Q(7) How can you handle multiple exceptions in Python?
#
# **Ans:-**
# We can handle multiple exceptions using several approaches depending on our specific needs.
# - Separate except blocks (Handle each exception differently)
# - Single except block with tuple (Handle multiple exceptions the same way)
# - Exception hierarchy (Handle base exceptions)
# - Multiple exceptions with different handling in one block
# - Re-raising exceptions with context
# - Using else and finally
#
# Q(8) What is the purpose of the with statement when handling files in Python?
#
# **Ans:-**
# The "with" statement in Python provides a clean and efficient way to handle resources for file operations. Its primary purpose is to ensure proper acquisition and release of resources, even if exceptions occur.
#
# The following points can be noted while using "with" with files:
# - Automatic Resource Management => Opens and closes files automatically. The file is closed when the block inside with ends, even if an error occurs.
# No need to manually call file.close()
# - Exception Safety => If an error (e.g., IOError, PermissionError) occurs inside the with block, Python ensures the file is properly closed before propagating the exception. It also prevents resource leaks (e.g., too many open files).
# - Cleaner and More Readable Code => Eliminates boilerplate try-finally blocks for cleanup.
# - Supports Context Managers => open() returns a context manager object, which defines __enter__() (setup) and __exit__() (cleanup). The with statement leverages these methods to manage resources.
#
# Q(9) What is the difference between multithreading and multiprocessing?
#
# **Ans:-**
# Both multithreading and multiprocessing allow concurrent execution of tasks, but they differ in how they manage system resources, memory, and Python's limitations (like the Global Interpreter Lock (GIL)).
# - Memory & Data Sharing =><br>
# In Multithreading, all threads share the same memory space (variables, objects). So, there is a risk of race conditions (use threading.Lock).<br>
# But in Multiprocessing, each process has its own memory (no shared state by default). So it requires Inter-Process Communication (IPC) (e.g., multiprocessing.Queue, Pipe).
# - Global Interpreter Lock (GIL)<br>
# In Multithreading, Python’s GIL allows only one thread to execute Python bytecode at a time. I/O-related tasks work well because threads release the GIL while waiting but the CPU-bound tasks (e.g., math) suffer because threads cannot run in parallel.<br>
# In Multiprocessing, each process has its own GIL, enabling true parallelism for CPU-bound tasks.
# - Performance<br>
# Multithreading wins because of low overhead (for APIs, file handling etc.)<br>
# Multiprocessing wins for CPU intensive works, like NumPy, ML applications etc.
#
# Q(10) What are the advantages of using logging in a program?
#
# **Ans:-**
# Logging is a critical practice in software development that provides structured, persistent records of program execution.
# - Debugging & Troubleshooting
# - Monitoring & Performance Analysis
# - Crash Investigation
# - Scalability & Maintenance
# - Better Than print() Statements
# - Security & Compliance
# - Structured Logging (Modern Approach)
#
# Q(11) What is memory management in Python?
#
# **Ans:-**
# Memory management in Python refers to how the Python interpreter allocates, uses, and frees memory for objects in your program. Python automates memory management. It optimizes performance and avoids leaks.
#
# - Dynamic Memory Allocation<br>
# Python dynamically allocates memory for objects (integers, lists, classes, etc.).
# - Garbage Collection (GC)<br>
# Python uses automatic garbage collection to reclaim unused memory.
# - Memory Pools & Object-Specific Allocators<br>
# Python uses private heaps for object storage.<br>
# Small objects (e.g., integers, tuples) use pre-allocated memory pools for efficiency.<br>
# Large objects (e.g., NumPy arrays) use the system allocator.
# - Memory Profiling & Optimization<br>
# Tools like tracemalloc, memory_profiler, and objgraph help analyze memory usage.
#
# Q(12) What are the basic steps involved in exception handling in Python?
#
# **Ans:-**
# Exception handling in Python allows us to gracefully manage errors and unexpected events without crashing our program.
# - Step 1<br>
# Use try and except Blocks
# - Step 2<br>
# Catch Specific Exceptions
# - Step 3<br>
# Use else for Success Cases
# - Step 4<br>
# Clean Up with finally
# - Step 5<br>
# Raise Custom Exceptions
# - Step 6<br>
# Chain Exceptions with raise from
# - Step 7<br>
# Log Exceptions
#
# Q(13) Why is memory management important in Python?
#
# **Ans:-**
# Memory management is crucial in Python to ensure efficient resource usage, prevent crashes, and optimize performance.
#
# - Prevents Memory Leaks
# - Optimizes Performance
# - Avoids Crashes in Resource-Limited Environments
# - Handles Cyclic References
# - Ensures Scalability
# - Facilitates Debugging
#
# Q(14) What is the role of try and except in exception handling?
#
# **Ans:-**
# In Python, try and except are fundamental constructs used for exception handling, allowing us to gracefully manage errors and prevent our program from crashing when unexpected situations occur.
#
# **Role of try and except:**<br>
# **try Block:**
#
# Contains the code that might raise an exception (e.g., dividing by zero, accessing a non-existent file).
#
# If an exception occurs inside try, Python stops executing the rest of the block and jumps to the matching except.
#
# **except Block:**
#
# Catches and handles the exception raised in the try block.
#
# We can specify which exceptions to catch (e.g., ValueError, TypeError) or use a generic except to catch all exceptions.
#
# If no exception occurs, the except block is skipped.
#
# Thus it helps in<br>
# - Preventing Program Crashes: Instead of stopping execution, you can log errors or provide fallback behavior.
# - Controlling Error Handling: Different exceptions can be handled differently.
# - Cleaning up with finally: Ensures resources (like files or network connections) are properly released.
#
# Q(15) How does Python's garbage collection system work?
#
# **Ans:-**
# Python’s garbage collection (GC) system automatically manages memory by reclaiming unused objects to free up resources. It primarily uses a combination of reference counting and a generational garbage collector to handle cyclic references.
#
# **Reference Counting (Primary Mechanism)**<br>
# Every object in Python has a reference count, which tracks how many variables or data structures point to it.
#
# When the reference count drops to zero, the object is immediately deallocated.
#
# **Generational Garbage Collector (Handles Cycles)**<br>
# To handle reference cycles (e.g., circular lists or graphs), Python uses a generational GC with three generations:<br>
# Generation 0 (Young): Newly created objects.<br>
# Generation 1 (Middle): Objects that survive one GC cycle.<br>
# Generation 2 (Old): Long-lived objects.
#
# Q(16) What is the purpose of the else block in exception handling?
#
# **Ans:-**
# In Python's exception handling, the "else block" serves a specific and often underutilized purpose. It executes only if the try block completes successfully without raising any exceptions. This makes it distinct from finally (which always runs) and except (which runs only on errors).
#
# -Separation of Concerns:<br>
# Code in the try block should only include statements that might raise exceptions.<br>
# The else block contains code that should run only if no exceptions occurred, keeping the logic clean.
# - Avoid Accidental Exception Catching:<br>
# If you place non-risky code in the try block, an unrelated exception might be caught unintentionally by except. The else block prevents this.
# - Clarity:<br>
# Makes it explicit which code is "protected" by exception handling and which is part of the happy path.
#
# Q(17) What are the common logging levels in Python?
#
# **Ans:-**
# In Python's logging module, logging levels categorize the severity of events, allowing us to filter and handle messages appropriately. Here are the standard levels (from lowest to highest severity):
#
# **Common Logging Levels**
# - DEBUG	10 => Detailed diagnostic info for developers (e.g., variable states).
# - INFO	20 => Confirmation that things are working as expected (e.g., "Server started").
# - WARNING	30 =>	Indicates potential issues (e.g., "Low disk space"). Non-critical.
# - ERROR	40 => Serious problems that disrupt functionality (e.g., "Failed to open DB").
# - CRITICAL	50 => Fatal errors causing program termination (e.g., "Out of memory").
#
# Q(18) What is the difference between os.fork() and multiprocessing in Python?
#
# **Ans:-**
# The followings are the differences between os.fork() and multiprocessing in Python.<br>
# **os.fork()**
# - Directly calls the Unix/Linux system call fork(), creating a child process that is an exact copy of the parent process (including memory, file descriptors, etc.).
# - The child process starts execution from the point where fork() was called.
#
# **multiprocessing Module**
# - Provides a cross-platform way to spawn processes using fork() (Unix) or spawn/forkserver (Windows).
# - Each process has isolated memory (no shared state by default).
# - Designed for parallelism, with tools like Queue, Pool, and Pipe.
#
# Q(19) What is the importance of closing a file in Python?
#
# **Ans:-**
# The Importance of Closing Files in Python:<br>
#
# **Resource Management**
# - File Descriptor Limit:<br>
# Every open file consumes a file descriptor (a system resource).<br>
# Operating systems impose limits on the number of open files per process.<br>
# Failing to close files can exhaust these limits<br>
# - Memory Leaks:<br>
# Unclosed files may hold memory buffers, leading to unnecessary resource usage.
#
# **Data Integrity**
# - Python uses buffering for file I/O (data isn’t written immediately to disk).
# If a program crashes or exits unexpectedly, buffered data may be lost.<br>
# Closing the file (close()) flushes the buffer, ensuring all data is saved.
#
# **Preventing Corruption**<br>
# - File Locking (OS-Level):
# Some OSs lock files while they’re open (e.g., Windows).<br>
# Other programs (or the same script) may fail to access the file if it’s not closed.
#
# Q(20) What is the difference between file.read() and file.readline() in Python?
#
# **Ans:-**
# In Python, file.read() and file.readline() are methods used to read data from a file, but they behave differently in terms of how they retrieve and return the content.
#
# **file.read([size])**<br>
# - Reads the entire file or a specified number of bytes/characters.
# - If no size argument is given, it reads all content until the end of the file (EOF).
# - If size is provided (e.g., read(100)), it reads up to that many bytes (binary mode) or characters (text mode).
# - A single string (text mode) or bytes object (binary mode) is returned.
# - Best for reading small files or when we need the entire content at once.
#
# **file.readline([size])**<br>
# - Reads a single line from the file (up to the newline character \n).
# - Reads until the next \n or EOF.
# - If size is specified, it reads up to that many characters but stops at \n.
# - Returns an empty string ("") at EOF.
# - A single line as a string (including the \n at the end) is returned.
# - Ideal for processing large files line by line (memory-efficient).
#
# Q(21) What is the logging module in Python used for?
#
# **Ans:-**
# The logging module in Python is a built-in library designed to track events that occur when software runs. It is used for recording log messages that help in debugging, monitoring, and analyzing applications.
#
# **Purpose of logging module**
# - Debugging: Log messages help identify issues during development and production.
# - Error Tracking: Records exceptions and errors for troubleshooting.
# - Monitoring Application Behavior: Tracks user activity, performance metrics, or system events.
# - Audit Logs: Maintains a record of security-related events (e.g., login attempts).
# - Configurable Log Levels: Different log levels allow filtering messages by severity.
# - Flexible Output Destinations: Logs can be written to Console (StreamHandler),
# Files (FileHandler), Email (SMTPHandler), External services (via custom handlers).
#
# Q(22) What is the os module in Python used for in file handling?
#
# **Ans:-**
# The os module in Python provides functions for interacting with the operating system for file and directory operations. It is used in file handling to manage paths, create/delete files, and perform system-level tasks.
# - File Path Manipulation<br>
# os.path.join(): Safely joins path components (handles OS-specific separators).<br>
# os.path.abspath(): Gets the absolute path of a file.<br>
# os.path.exists(): Checks if a file/directory exists.<br>
# os.path.isfile() / os.path.isdir(): Checks if a path is a file or directory.
# - File and Directory Operations<br>
# os.listdir(): Lists files/folders in a directory.<br>
# os.mkdir() / os.makedirs(): Creates a directory (or nested directories).<br>
# os.remove(): Deletes a file.<br>
# os.rmdir(): Removes an empty directory.<br>
# os.rename(): Renames/moves a file
# - File Metadata & Permissions<br>
# os.stat(): Gets file stats (size, modification time, etc.)<br>
# os.chmod(): Changes file permissions.
# -Working with File Paths Across OS<br>
# os.sep: OS-specific path separator (\ on Windows, / on Linux)<br>
# os.getcwd(): Gets the current working directory.<br>
# os.chdir(): Changes the working directory.
#
# Q(23) What are the challenges associated with memory management in Python?
#
# **Ans:-**
# Memory management in Python is mostly handled automatically by its garbage collector and reference counting. But there are some challanges that a programmer has to face related with memory management.
#
# Some of these challanges are listed below:
# - Memory Leaks: Unintentional retention of objects (e.g., circular references, caches, global variables).
# - High Memory Usage: Inefficient data structures (e.g., lists vs. generators) and Unoptimized object storage.
# - Garbage Collection Overhead: Python’s Garbage collector (especially generational GC) can introduce latency in real-time systems.
# - Fragmentation: Frequent allocation/deallocation of objects leads to fragmented memory. This slows allocations or MemoryError even if total free memory exists.
# - Large Data Structures: Native Python objects (e.g., lists, dicts) have high overhead. A list in Pythoin consumes 4 times more memory than an array in C.
# - Reference Counting Limitations: Reference counting alone can’t handle circular references.
# - Multithreading & Memory: Python’s Global Interpreter Lock(GIL) serializes memory access, limiting parallel memory operations.
#
# Q(24) How do you raise an exception manually in Python?
#
# **Ans:-**
# In Python, we can manually raise an exception using the "raise" keyword. This is useful for enforcing constraints, handling edge cases, or signaling errors in our code.
#
# Q(25) Why is it important to use multithreading in certain applications?
#
# **Ans:-**
# Multithreading is crucial in certain applications because it enables concurrent execution, improving performance, responsiveness, and efficiency—especially in tasks involving I/O-bound operations, real-time processing, or parallel processing.
# - Improved Performance for I/O-Bound Tasks
# - Responsiveness in GUI/Real-Time Applications
# - Efficient Resource Utilization
# - Parallelism in Multi-Core Systems (Despite the GIL)

# %%
# Q(1) How can you open a file for writing in Python and write a string to it?

# Open the file in write mode ('w')
with open("example.txt", "w") as file:
    file.write("Hello, World!")  # Writes the string to the file

# %%
with open("example.txt", "a") as file:
    file.write("\nThis is a new line.")  # Appends text

# %%
lines = ["First line\n", "Second line\n", "Third line\n"]

with open("example.txt", "w") as file:
    file.writelines(lines)  # Writes all lines at once

# %%
# Q(2) Write a Python program to read the contents of a file and print each
# line.

# Method 1: Using readlines() (stores all lines in memory)
with open('example.txt', 'r') as file:
    lines = file.readlines()
    for line in lines:
        print(line, end='')  # end='' removes extra newlines since each line already has one

print("\n---")
# Out:
# First line
# Second line
# Third line
#
# ---

# %%
# Method 2: Iterating directly over the file object (memory efficient)
with open('example.txt', 'r') as file:
    for line in file:
        print(line, end='')

print("\n---")
# Out:
# First line
# Second line
# Third line
#
# ---

# %%
# Method 3: Using read() and splitting lines
with open('example.txt', 'r') as file:
    content = file.read()
    for line in content.split('\n'):
        print(line)
# Out:
# First line
# Second line
# Third line

# %%
# Q(3) How would you handle a case where the file doesn't exist while trying to
# open it for reading?

# Using try-except is the most popuar way is to catch FileNotFoundError:

filename = "example1.txt"

try:
    with open(filename, 'r') as file:
        for line in file:
            print(line, end='')
except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist.")
except IOError as e:
    print(f"An I/O error occurred: {e}")
# Out:
# Error: The file 'example1.txt' does not exist.

# %%
# Q(4) Write a Python script that reads from one file and writes its content to
# another file.

def copy_file_content(source_file, destination_file):
    """
    Copies content from source_file to destination_file.

    Args:
        source_file (str): Path to the source file to read from
        destination_file (str): Path to the destination file to write to
    """
    try:
        # Open source file for reading
        with open(source_file, 'r') as src:
            # Read all content from source file
            content = src.read()

            # Open destination file for writing
            with open(destination_file, 'w') as dest:
                # Write content to destination file
                dest.write(content)

        print(f"Successfully copied content from {source_file} to {destination_file}")

    except FileNotFoundError:
        print(f"Error: The file {source_file} does not exist")
    except PermissionError:
        print(f"Error: Permission denied when accessing files")
    except Exception as e:
        print(f"An unexpected error occurred: {str(e)}")

# Example usage
if __name__ == "__main__":
    source = "input.txt"  # Change to your source file path
    destination = "output.txt"  # Change to your destination file path
    copy_file_content(source, destination)
# Out:
# Error: The file input.txt does not exist

# %%
# Q(5)  How would you catch and handle division by zero error in Python?

try:
    result = 10 / 0
except ZeroDivisionError:
    print("Error: Cannot divide by zero!")
# Out:
# Error: Cannot divide by zero!

# %%
# Q(6) Write a Python program that logs an error message to a log file when a
# division by zero exception occurs.

import logging

# Configure logging to write to a file
logging.basicConfig(
    filename='division_errors.log',
    level=logging.ERROR,
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

def divide_numbers(a, b):
    try:
        result = a / b
        print(f"Result: {result}")
        return result
    except ZeroDivisionError:
        error_msg = f"Division by zero attempted: {a}/{b}"
        logging.error(error_msg)
        print(f"Error: {error_msg} (Logged to division_errors.log)")
        return None

# Example usage
if __name__ == "__main__":
    print("Division Calculator")
    print("------------------")

    while True:
        try:
            num1 = float(input("Enter numerator (or 'q' to quit): "))
            if str(num1).lower() == 'q':
                break
            num2 = float(input("Enter denominator: "))

            divide_numbers(num1, num2)

        except ValueError:
            print("Error: Please enter valid numbers!")
        except KeyboardInterrupt:
            print("\nProgram terminated.")
            break

print("Goodbye!")
# Out:
# Division Calculator
# ------------------
# Enter numerator (or 'q' to quit): 8
# Enter denominator: 2
# Result: 4.0
# Enter numerator (or 'q' to quit): q
# Error: Please enter valid numbers!
# Enter numerator (or 'q' to quit): q
# Error: Please enter valid numbers!
# Enter numerator (or 'q' to quit): Q
# Error: Please enter valid numbers!
# Enter numerator (or 'q' to quit):
# Error: Please enter valid numbers!
# Enter numerator (or 'q' to quit):
# Error: Please enter valid numbers!
# Enter numerator (or 'q' to quit):
# Error: Please enter valid numbers!
#
# Program terminated.
# Goodbye!

# %%
# Q(7) How do you log information at different levels (INFO, ERROR, WARNING) in
# Python using the logging module?

import logging

# Basic configuration (writes to console)
logging.basicConfig(
    level=logging.DEBUG,  # Minimum level to capture
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# Example log messages
logging.debug("Debugging details")      # Level 10 (verbose)
logging.info("Program started")         # Level 20 (normal operation)
logging.warning("Low disk space")       # Level 30 (potential issue)
logging.error("Failed to open file")    # Level 40 (serious problem)
logging.critical("Server crashed")      # Level 50 (fatal error)
# Out:
# WARNING:root:Low disk space
# ERROR:root:Failed to open file
# CRITICAL:root:Server crashed

# %%
# Q(8) Write a program to handle a file opening error using exception handling.

import logging
import sys

def read_file_safely(filename):
    """
    Attempts to open and read a file, handling common errors gracefully.

    Args:
        filename (str): Path to the file to be read

    Returns:
        str: Content of the file if successful, None otherwise
    """
    try:
        with open(filename, 'r') as file:
            content = file.read()
            logging.info(f"Successfully read file: {filename}")
            return content

    except FileNotFoundError:
        logging.error(f"File not found: {filename}")
        print(f"Error: The file '{filename}' does not exist.", file=sys.stderr)
    except PermissionError:
        logging.error(f"Permission denied for file: {filename}")
        print(f"Error: You don't have permission to read '{filename}'.", file=sys.stderr)
    except IsADirectoryError:
        logging.error(f"Attempted to read a directory: {filename}")
        print(f"Error: '{filename}' is a directory, not a file.", file=sys.stderr)
    except UnicodeDecodeError:
        logging.error(f"Encoding error in file: {filename}")
        print(f"Error: Could not decode the contents of '{filename}'.", file=sys.stderr)
    except OSError as e:
        logging.error(f"OS error occurred with file {filename}: {str(e)}")
        print(f"System error: {str(e)}", file=sys.stderr)
    except Exception as e:
        logging.critical(f"Unexpected error with file {filename}: {str(e)}")
        print(f"An unexpected error occurred: {str(e)}", file=sys.stderr)

    return None

def main():
    # Configure logging
    logging.basicConfig(
        filename='file_operations.log',
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s'
    )

    # Example usage
    filename = input("Enter the file path to read: ")
    content = read_file_safely(filename)

    if content is not None:
        print("\nFile contents:")
        print("-" * 40)
        print(content)
        print("-" * 40)
    else:
        print("Failed to read the file.")

if __name__ == "__main__":
    main()
# Out:
# Enter the file path to read: c:\Python
# ERROR:root:File not found: c:\Python
# Failed to read the file.
# Error: The file 'c:\Python' does not exist.

# %%
# Q(9) How can you read a file line by line and store its content in a list in
# Python.

# Method 1

with open('example.txt', 'r') as file:
    lines = file.readlines()  # Reads all lines into a list

# Remove newline characters from each line
lines = [line.strip() for line in lines]

print(lines)
# Out:
# ['First line', 'Second line', 'Third line']

# %%
# Method 2

with open('example.txt', 'r') as file:
    lines = list(file)  # Converts file lines into a list

# Strip newlines (optional)
lines = [line.strip() for line in lines]

print(lines)
# Out:
# ['First line', 'Second line', 'Third line']

# %%
# Q(10) How can you append data to an existing file in Python?

# Appends single line

with open('data.txt', 'a') as file:
    file.write("This will be appended.\n")  # \n adds a new line

# %%
# Appends multiple lines

lines_to_add = ["Line 1\n", "Line 2\n", "Line 3\n"]

with open('data.txt', 'a') as file:
    file.writelines(lines_to_add)  # Appends each string in the list

# %%
# Q(11) Write a Python program that uses a try-except block to handle an error
# when attempting to access a dictionary key that doesn't exist.

my_dict = {"name": "Anoop", "age": 49, "city": "Muzaffarpur"}

try:
    print("Occupation:", my_dict["occupation"])  # Key doesn't exist
except KeyError:
    print("Error: The key 'occupation' does not exist in the dictionary.")
# Out:
# Error: The key 'occupation' does not exist in the dictionary.

# %%
# Q(12) Write a program that demonstrates using multiple except blocks to handle
# different types of exceptions.

def handle_operations():
    try:
        # Example 1: Handle division (ZeroDivisionError)
        num = int(input("Enter a numerator: "))
        den = int(input("Enter a denominator: "))
        result = num / den
        print(f"Division result: {result}")

        # Example 2: Handle file operations (FileNotFoundError)
        filename = input("Enter a filename to read: ")
        with open(filename, 'r') as file:
            content = file.read()
            print(f"File content:\n{content}")

        # Example 3: Handle list index (IndexError)
        my_list = [10, 20, 30]
        index = int(input(f"Enter an index (0-2) to access from {my_list}: "))
        print(f"Value at index {index}: {my_list[index]}")

    except ValueError:
        print("Error: Invalid input (expected an integer).")
    except ZeroDivisionError:
        print("Error: Cannot divide by zero!")
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
    except IndexError:
        print(f"Error: Index {index} is out of range.")
    except Exception as e:
        print(f"An unexpected error occurred: {type(e).__name__} - {e}")
    else:
        print("All operations completed successfully!")
    finally:
        print("Program execution complete.\n")

# Run the program
if __name__ == "__main__":
    handle_operations()
# Out:
# Enter a numerator: 8
# Enter a denominator: 2
# Division result: 4.0
# Enter a filename to read: exapmle
# Error: File 'exapmle' not found.
# Program execution complete.

# %%
# Q(13) How would you check if a file exists before attempting to read it in
# Python.

import os

file_path = "check.txt"

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
    print("File content:", content)
else:
    print(f"Error: File '{file_path}' does not exist.")
# Out:
# Error: File 'check.txt' does not exist.

# %%
# Q(14) Write a program that uses the logging module to log both informational
# and error messages.

import logging
import os
import math

def setup_logging():
    """Configure logging to write to both console and file with different levels"""
    # Create logs directory if it doesn't exist
    os.makedirs("logs", exist_ok=True)

    # Basic configuration
    logging.basicConfig(
        level=logging.DEBUG,  # Lowest level to capture
        format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
        handlers=[
            logging.FileHandler("logs/app.log"),  # All logs to file
            logging.StreamHandler()               # Only warnings+ to console
        ]
    )

    # Set console handler to only show WARNING+ messages
    console_handler = logging.StreamHandler()
    console_handler.setLevel(logging.WARNING)
    logging.getLogger().addHandler(console_handler)

def calculate_square_root(number):
    """Demonstrate logging at different levels"""
    try:
        logging.info(f"Calculating square root of {number}")

        if number < 0:
            logging.warning("Negative number provided - using absolute value")
            number = abs(number)

        result = math.sqrt(number)
        logging.info(f"Result: {result}")
        return result

    except Exception as e:
        logging.error(f"Error in calculation: {str(e)}", exc_info=True)
        return None

def main():
    setup_logging()

    logging.info("Program started")

    # Example calculations
    calculate_square_root(16)     # Normal operation
    calculate_square_root(-4)     # Warning case
    calculate_square_root("text") # Error case

    logging.info("Program completed")

if __name__ == "__main__":
    main()
# Out:
# WARNING:root:Negative number provided - using absolute value
# Negative number provided - using absolute value
# ERROR:root:Error in calculation: '<' not supported between instances of 'str' and 'int'
# Traceback (most recent call last):
#   File "/tmp/ipython-input-29-813391973.py", line 33, in calculate_square_root
#     if number < 0:
#        ^^^^^^^^^^
# TypeError: '<' not supported between instances of 'str' and 'int'
# Error in calculation: '<' not supported between instances of 'str' and 'int'
# Traceback (most recent call last):
#   File "/tmp/ipython-input-29-813391973.py", line 33, in calculate_square_root
#     if number < 0:
#        ^^^^^^^^^^
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
# Q(15) Write a Python program that prints the content of a file and handles the
# case when the file is empty.

import os

def print_file_contents(filename):
    """Prints the contents of a file, handling empty files gracefully."""
    try:
        # Check if file exists first
        if not os.path.exists(filename):
            print(f"Error: File '{filename}' does not exist.")
            return

        # Check if file is empty
        if os.path.getsize(filename) == 0:
            print(f"Note: The file '{filename}' is empty.")
            return

        # Read and print file contents
        with open(filename, 'r') as file:
            content = file.read()
            print(f"Contents of '{filename}':")
            print("-" * 40)
            print(content)
            print("-" * 40)

    except PermissionError:
        print(f"Error: No permission to read '{filename}'.")
    except Exception as e:
        print(f"An unexpected error occurred: {str(e)}")

# Example usage
if __name__ == "__main__":
    filename = input("Enter the path of the file to read: ")
    print_file_contents(filename)
# Out:
# Enter the path of the file to read: example.txt
# Contents of 'example.txt':
# ----------------------------------------
# First line
# Second line
# Third line
#
# ----------------------------------------

# %%
# !pip install memory_profiler
# Out:
# Requirement already satisfied: memory_profiler in /usr/local/lib/python3.11/dist-packages (0.61.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from memory_profiler) (5.9.5)

# %%
# Q(16) Demonstrate how to use memory profiling to check the memory usage of
# a small program.

# Memory profiling is a technique used to measure how much memory your program
# uses during execution. Here's how to perform memory profiling on a small
# Python program using the memory-profiler package.

# memory_demo_profiled.py
import numpy as np
from memory_profiler import profile

@profile
def create_large_array(size):
    """Create and return a large numpy array"""
    arr = np.random.rand(size, size)
    return arr

@profile
def process_data():
    """Perform memory-intensive operations"""
    data1 = create_large_array(1000)
    data2 = create_large_array(1000)
    result = np.dot(data1, data2)
    return result

if __name__ == "__main__":
    process_data()
# Out:
# ERROR: Could not find file /tmp/ipython-input-10-2201665239.py
# ERROR: Could not find file /tmp/ipython-input-10-2201665239.py
# ERROR: Could not find file /tmp/ipython-input-10-2201665239.py

# %%
# Q(17) Write a Python program to create and write a list of numbers to a file,
# one number per line

def write_numbers_to_file(numbers, filename):
    """
    Writes a list of numbers to a file, one number per line.

    Args:
        numbers (list): List of numbers to write
        filename (str): Name of the file to create/write to
    """
    try:
        with open(filename, 'w') as file:
            for number in numbers:
                file.write(f"{number}\n")
        print(f"Successfully wrote {len(numbers)} numbers to {filename}")
    except IOError as e:
        print(f"Error writing to file: {e}")

# Example usage
if __name__ == "__main__":
    # Create a list of numbers (could be integers or floats)
    numbers = [1, 2, 3, 4, 5, 10, 20, 30, 3.14, 2.718]

    # Specify the output filename
    output_file = "numbers.txt"

    # Write the numbers to file
    write_numbers_to_file(numbers, output_file)
# Out:
# Successfully wrote 10 numbers to numbers.txt

# %%
# Q(18) How would you implement a basic logging setup that logs to a file with
# rotation after 1MB.

import logging
from logging.handlers import RotatingFileHandler

def setup_logging(log_file='app.log', max_size=1_000_000, backup_count=5):
    """
    Set up logging with file rotation.

    Args:
        log_file (str): Path to the log file
        max_size (int): Maximum file size in bytes before rotation (default: 1MB)
        backup_count (int): Number of backup files to keep (default: 5)
    """
    # Create a logger
    logger = logging.getLogger()
    logger.setLevel(logging.DEBUG)  # Set to lowest level

    # Create formatter
    formatter = logging.Formatter(
        '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
    )

    # Create rotating file handler
    file_handler = RotatingFileHandler(
        filename=log_file,
        maxBytes=max_size,
        backupCount=backup_count
    )
    file_handler.setFormatter(formatter)

    # Add handler to the logger
    logger.addHandler(file_handler)

    # Optionally add console handler
    console_handler = logging.StreamHandler()
    console_handler.setFormatter(formatter)
    logger.addHandler(console_handler)

    return logger

# Example usage
if __name__ == "__main__":
    logger = setup_logging('my_app.log')

    # Log some messages
    logger.debug("This is a debug message")
    logger.info("This is an info message")
    logger.warning("This is a warning message")
    logger.error("This is an error message")
    logger.critical("This is a critical message")

    # Generate enough logs to trigger rotation
    for i in range(1000):
        logger.info(f"Log message {i}")
# Out:
# DEBUG:root:This is a debug message
# 2025-07-10 06:43:19,375 - root - DEBUG - This is a debug message
# INFO:root:This is an info message
# 2025-07-10 06:43:19,377 - root - INFO - This is an info message
# WARNING:root:This is a warning message
# 2025-07-10 06:43:19,380 - root - WARNING - This is a warning message
# ERROR:root:This is an error message
# 2025-07-10 06:43:19,382 - root - ERROR - This is an error message
# CRITICAL:root:This is a critical message
# 2025-07-10 06:43:19,384 - root - CRITICAL - This is a critical message
# INFO:root:Log message 0
# 2025-07-10 06:43:19,385 - root - INFO - Log message 0
# INFO:root:Log message 1
# 2025-07-10 06:43:19,387 - root - INFO - Log message 1
# INFO:root:Log message 2
# 2025-07-10 06:43:19,388 - root - INFO - Log message 2
# INFO:root:Log message 3
# 2025-07-10 06:43:19,389 - root - INFO - Log message 3
# INFO:root:Log message 4
# 2025-07-10 06:43:19,390 - root - INFO - Log message 4
# INFO:root:Log message 5
# 2025-07-10 06:43:19,392 - root - INFO - Log message 5
# INFO:root:Log message 6
# 2025-07-10 06:43:19,393 - root - INFO - Log message 6
# INFO:root:Log message 7
# 2025-07-10 06:43:19,394 - root - INFO - Log message 7
# INFO:root:Log message 8
# 2025-07-10 06:43:19,395 - root - INFO - Log message 8
# INFO:root:Log message 9
# 2025-07-10 06:43:19,396 - root - INFO - Log message 9
# INFO:root:Log message 10
# 2025-07-10 06:43:19,404 - root - INFO - Log message 10
# INFO:root:Log message 11
# 2025-07-10 06:43:19,406 - root - INFO - Log message 11
# INFO:root:Log message 12
# 2025-07-10 06:43:19,408 - root - INFO - Log message 12
# INFO:root:Log message 13
# 2025-07-10 06:43:19,410 - root - INFO - Log message 13
# INFO:root:Log message 14
# 2025-07-10 06:43:19,412 - root - INFO - Log message 14
# INFO:root:Log message 15
# 2025-07-10 06:43:19,414 - root - INFO - Log message 15
# INFO:root:Log message 16
# 2025-07-10 06:43:19,416 - root - INFO - Log message 16
# INFO:root:Log message 17
# 2025-07-10 06:43:19,417 - root - INFO - Log message 17
# INFO:root:Log message 18
# 2025-07-10 06:43:19,421 - root - INFO - Log message 18
# INFO:root:Log message 19
# 2025-07-10 06:43:19,424 - root - INFO - Log message 19
# INFO:root:Log message 20
# 2025-07-10 06:43:19,426 - root - INFO - Log message 20
# INFO:root:Log message 21
# 2025-07-10 06:43:19,427 - root - INFO - Log message 21
# INFO:root:Log message 22
# 2025-07-10 06:43:19,428 - root - INFO - Log message 22
# INFO:root:Log message 23
# 2025-07-10 06:43:19,430 - root - INFO - Log message 23
# INFO:root:Log message 24
# 2025-07-10 06:43:19,431 - root - INFO - Log message 24
# INFO:root:Log message 25
# 2025-07-10 06:43:19,432 - root - INFO - Log message 25
# INFO:root:Log message 26
# 2025-07-10 06:43:19,433 - root - INFO - Log message 26
# INFO:root:Log message 27
# 2025-07-10 06:43:19,436 - root - INFO - Log message 27
# INFO:root:Log message 28
# 2025-07-10 06:43:19,438 - root - INFO - Log message 28
# INFO:root:Log message 29
# 2025-07-10 06:43:19,439 - root - INFO - Log message 29
# INFO:root:Log message 30
# 2025-07-10 06:43:19,440 - root - INFO - Log message 30
# INFO:root:Log message 31
# 2025-07-10 06:43:19,441 - root - INFO - Log message 31
# INFO:root:Log message 32
# 2025-07-10 06:43:19,442 - root - INFO - Log message 32
# INFO:root:Log message 33
# 2025-07-10 06:43:19,443 - root - INFO - Log message 33
# INFO:root:Log message 34
# 2025-07-10 06:43:19,445 - root - INFO - Log message 34
# INFO:root:Log message 35
# 2025-07-10 06:43:19,448 - root - INFO - Log message 35
# INFO:root:Log message 36
# 2025-07-10 06:43:19,450 - root - INFO - Log message 36
# INFO:root:Log message 37
# 2025-07-10 06:43:19,451 - root - INFO - Log message 37
# INFO:root:Log message 38
# 2025-07-10 06:43:19,452 - root - INFO - Log message 38
# INFO:root:Log message 39
# 2025-07-10 06:43:19,454 - root - INFO - Log message 39
# INFO:root:Log message 40
# 2025-07-10 06:43:19,455 - root - INFO - Log message 40
# INFO:root:Log message 41
# 2025-07-10 06:43:19,456 - root - INFO - Log message 41
# INFO:root:Log message 42
# 2025-07-10 06:43:19,457 - root - INFO - Log message 42
# INFO:root:Log message 43
# 2025-07-10 06:43:19,458 - root - INFO - Log message 43
# INFO:root:Log message 44
# 2025-07-10 06:43:19,460 - root - INFO - Log message 44
# INFO:root:Log message 45
# 2025-07-10 06:43:19,461 - root - INFO - Log message 45
# INFO:root:Log message 46
# 2025-07-10 06:43:19,463 - root - INFO - Log message 46
# INFO:root:Log message 47
# 2025-07-10 06:43:19,464 - root - INFO - Log message 47
# INFO:root:Log message 48
# 2025-07-10 06:43:19,465 - root - INFO - Log message 48
# INFO:root:Log message 49
# 2025-07-10 06:43:19,466 - root - INFO - Log message 49
# INFO:root:Log message 50
# 2025-07-10 06:43:19,468 - root - INFO - Log message 50
# INFO:root:Log message 51
# 2025-07-10 06:43:19,469 - root - INFO - Log message 51
# INFO:root:Log message 52
# 2025-07-10 06:43:19,471 - root - INFO - Log message 52
# INFO:root:Log message 53
# 2025-07-10 06:43:19,472 - root - INFO - Log message 53
# INFO:root:Log message 54
# 2025-07-10 06:43:19,473 - root - INFO - Log message 54
# INFO:root:Log message 55
# 2025-07-10 06:43:19,475 - root - INFO - Log message 55
# INFO:root:Log message 56
# 2025-07-10 06:43:19,476 - root - INFO - Log message 56
# INFO:root:Log message 57
# 2025-07-10 06:43:19,477 - root - INFO - Log message 57
# INFO:root:Log message 58
# 2025-07-10 06:43:19,478 - root - INFO - Log message 58
# INFO:root:Log message 59
# 2025-07-10 06:43:19,479 - root - INFO - Log message 59
# INFO:root:Log message 60
# 2025-07-10 06:43:19,481 - root - INFO - Log message 60
# INFO:root:Log message 61
# 2025-07-10 06:43:19,482 - root - INFO - Log message 61
# INFO:root:Log message 62
# 2025-07-10 06:43:19,483 - root - INFO - Log message 62
# INFO:root:Log message 63
# 2025-07-10 06:43:19,484 - root - INFO - Log message 63
# INFO:root:Log message 64
# 2025-07-10 06:43:19,485 - root - INFO - Log message 64
# INFO:root:Log message 65
# 2025-07-10 06:43:19,486 - root - INFO - Log message 65
# INFO:root:Log message 66
# 2025-07-10 06:43:19,487 - root - INFO - Log message 66
# INFO:root:Log message 67
# 2025-07-10 06:43:19,489 - root - INFO - Log message 67
# INFO:root:Log message 68
# 2025-07-10 06:43:19,490 - root - INFO - Log message 68
# INFO:root:Log message 69
# 2025-07-10 06:43:19,492 - root - INFO - Log message 69
# INFO:root:Log message 70
# 2025-07-10 06:43:19,494 - root - INFO - Log message 70
# INFO:root:Log message 71
# 2025-07-10 06:43:19,496 - root - INFO - Log message 71
# INFO:root:Log message 72
# 2025-07-10 06:43:19,497 - root - INFO - Log message 72
# INFO:root:Log message 73
# 2025-07-10 06:43:19,498 - root - INFO - Log message 73
# INFO:root:Log message 74
# 2025-07-10 06:43:19,499 - root - INFO - Log message 74
# INFO:root:Log message 75
# 2025-07-10 06:43:19,501 - root - INFO - Log message 75
# INFO:root:Log message 76
# 2025-07-10 06:43:19,502 - root - INFO - Log message 76
# INFO:root:Log message 77
# 2025-07-10 06:43:19,503 - root - INFO - Log message 77
# INFO:root:Log message 78
# 2025-07-10 06:43:19,504 - root - INFO - Log message 78
# INFO:root:Log message 79
# 2025-07-10 06:43:19,505 - root - INFO - Log message 79
# INFO:root:Log message 80
# 2025-07-10 06:43:19,506 - root - INFO - Log message 80
# INFO:root:Log message 81
# 2025-07-10 06:43:19,507 - root - INFO - Log message 81
# INFO:root:Log message 82
# 2025-07-10 06:43:19,509 - root - INFO - Log message 82
# INFO:root:Log message 83
# 2025-07-10 06:43:19,510 - root - INFO - Log message 83
# INFO:root:Log message 84
# 2025-07-10 06:43:19,511 - root - INFO - Log message 84
# INFO:root:Log message 85
# 2025-07-10 06:43:19,512 - root - INFO - Log message 85
# INFO:root:Log message 86
# 2025-07-10 06:43:19,513 - root - INFO - Log message 86
# INFO:root:Log message 87
# 2025-07-10 06:43:19,514 - root - INFO - Log message 87
# INFO:root:Log message 88
# 2025-07-10 06:43:19,516 - root - INFO - Log message 88
# INFO:root:Log message 89
# 2025-07-10 06:43:19,524 - root - INFO - Log message 89
# INFO:root:Log message 90
# 2025-07-10 06:43:19,527 - root - INFO - Log message 90
# INFO:root:Log message 91
# 2025-07-10 06:43:19,539 - root - INFO - Log message 91
# INFO:root:Log message 92
# 2025-07-10 06:43:19,570 - root - INFO - Log message 92
# INFO:root:Log message 93
# 2025-07-10 06:43:19,572 - root - INFO - Log message 93
# INFO:root:Log message 94
# 2025-07-10 06:43:19,574 - root - INFO - Log message 94
# INFO:root:Log message 95
# 2025-07-10 06:43:19,575 - root - INFO - Log message 95
# INFO:root:Log message 96
# 2025-07-10 06:43:19,577 - root - INFO - Log message 96
# INFO:root:Log message 97
# 2025-07-10 06:43:19,579 - root - INFO - Log message 97
# INFO:root:Log message 98
# 2025-07-10 06:43:19,580 - root - INFO - Log message 98
# INFO:root:Log message 99
# 2025-07-10 06:43:19,582 - root - INFO - Log message 99
# INFO:root:Log message 100
# 2025-07-10 06:43:19,584 - root - INFO - Log message 100
# INFO:root:Log message 101
# 2025-07-10 06:43:19,585 - root - INFO - Log message 101
# INFO:root:Log message 102
# 2025-07-10 06:43:19,587 - root - INFO - Log message 102
# INFO:root:Log message 103
# 2025-07-10 06:43:19,588 - root - INFO - Log message 103
# INFO:root:Log message 104
# 2025-07-10 06:43:19,590 - root - INFO - Log message 104
# INFO:root:Log message 105
# 2025-07-10 06:43:19,591 - root - INFO - Log message 105
# INFO:root:Log message 106
# 2025-07-10 06:43:19,600 - root - INFO - Log message 106
# INFO:root:Log message 107
# 2025-07-10 06:43:19,602 - root - INFO - Log message 107
# INFO:root:Log message 108
# 2025-07-10 06:43:19,605 - root - INFO - Log message 108
# INFO:root:Log message 109
# 2025-07-10 06:43:19,606 - root - INFO - Log message 109
# INFO:root:Log message 110
# 2025-07-10 06:43:19,610 - root - INFO - Log message 110
# INFO:root:Log message 111
# 2025-07-10 06:43:19,612 - root - INFO - Log message 111
# INFO:root:Log message 112
# 2025-07-10 06:43:19,614 - root - INFO - Log message 112
# INFO:root:Log message 113
# 2025-07-10 06:43:19,616 - root - INFO - Log message 113
# INFO:root:Log message 114
# 2025-07-10 06:43:19,619 - root - INFO - Log message 114
# INFO:root:Log message 115
# 2025-07-10 06:43:19,621 - root - INFO - Log message 115
# INFO:root:Log message 116
# 2025-07-10 06:43:19,623 - root - INFO - Log message 116
# INFO:root:Log message 117
# 2025-07-10 06:43:19,625 - root - INFO - Log message 117
# INFO:root:Log message 118
# 2025-07-10 06:43:19,627 - root - INFO - Log message 118
# INFO:root:Log message 119
# 2025-07-10 06:43:19,629 - root - INFO - Log message 119
# INFO:root:Log message 120
# 2025-07-10 06:43:19,631 - root - INFO - Log message 120
# INFO:root:Log message 121
# 2025-07-10 06:43:19,635 - root - INFO - Log message 121
# INFO:root:Log message 122
# 2025-07-10 06:43:19,637 - root - INFO - Log message 122
# INFO:root:Log message 123
# 2025-07-10 06:43:19,639 - root - INFO - Log message 123
# INFO:root:Log message 124
# 2025-07-10 06:43:19,642 - root - INFO - Log message 124
# INFO:root:Log message 125
# 2025-07-10 06:43:19,644 - root - INFO - Log message 125
# INFO:root:Log message 126
# 2025-07-10 06:43:19,646 - root - INFO - Log message 126
# INFO:root:Log message 127
# 2025-07-10 06:43:19,647 - root - INFO - Log message 127
# INFO:root:Log message 128
# 2025-07-10 06:43:19,650 - root - INFO - Log message 128
# INFO:root:Log message 129
# 2025-07-10 06:43:19,652 - root - INFO - Log message 129
# INFO:root:Log message 130
# 2025-07-10 06:43:19,654 - root - INFO - Log message 130
# INFO:root:Log message 131
# 2025-07-10 06:43:19,657 - root - INFO - Log message 131
# INFO:root:Log message 132
# 2025-07-10 06:43:19,659 - root - INFO - Log message 132
# INFO:root:Log message 133
# 2025-07-10 06:43:19,660 - root - INFO - Log message 133
# INFO:root:Log message 134
# 2025-07-10 06:43:19,662 - root - INFO - Log message 134
# INFO:root:Log message 135
# 2025-07-10 06:43:19,664 - root - INFO - Log message 135
# INFO:root:Log message 136
# 2025-07-10 06:43:19,667 - root - INFO - Log message 136
# INFO:root:Log message 137
# 2025-07-10 06:43:19,668 - root - INFO - Log message 137
# INFO:root:Log message 138
# 2025-07-10 06:43:19,671 - root - INFO - Log message 138
# INFO:root:Log message 139
# 2025-07-10 06:43:19,674 - root - INFO - Log message 139
# INFO:root:Log message 140
# 2025-07-10 06:43:19,676 - root - INFO - Log message 140
# INFO:root:Log message 141
# 2025-07-10 06:43:19,678 - root - INFO - Log message 141
# INFO:root:Log message 142
# 2025-07-10 06:43:19,679 - root - INFO - Log message 142
# INFO:root:Log message 143
# 2025-07-10 06:43:19,682 - root - INFO - Log message 143
# INFO:root:Log message 144
# 2025-07-10 06:43:19,683 - root - INFO - Log message 144
# INFO:root:Log message 145
# 2025-07-10 06:43:19,684 - root - INFO - Log message 145
# INFO:root:Log message 146
# 2025-07-10 06:43:19,685 - root - INFO - Log message 146
# INFO:root:Log message 147
# 2025-07-10 06:43:19,686 - root - INFO - Log message 147
# INFO:root:Log message 148
# 2025-07-10 06:43:19,687 - root - INFO - Log message 148
# INFO:root:Log message 149
# 2025-07-10 06:43:19,688 - root - INFO - Log message 149
# INFO:root:Log message 150
# 2025-07-10 06:43:19,690 - root - INFO - Log message 150
# INFO:root:Log message 151
# 2025-07-10 06:43:19,691 - root - INFO - Log message 151
# INFO:root:Log message 152
# 2025-07-10 06:43:19,693 - root - INFO - Log message 152
# INFO:root:Log message 153
# 2025-07-10 06:43:19,694 - root - INFO - Log message 153
# INFO:root:Log message 154
# 2025-07-10 06:43:19,696 - root - INFO - Log message 154
# INFO:root:Log message 155
# 2025-07-10 06:43:19,697 - root - INFO - Log message 155
# INFO:root:Log message 156
# 2025-07-10 06:43:19,698 - root - INFO - Log message 156
# INFO:root:Log message 157
# 2025-07-10 06:43:19,700 - root - INFO - Log message 157
# INFO:root:Log message 158
# 2025-07-10 06:43:19,701 - root - INFO - Log message 158
# INFO:root:Log message 159
# 2025-07-10 06:43:19,702 - root - INFO - Log message 159
# INFO:root:Log message 160
# 2025-07-10 06:43:19,704 - root - INFO - Log message 160
# INFO:root:Log message 161
# 2025-07-10 06:43:19,705 - root - INFO - Log message 161
# INFO:root:Log message 162
# 2025-07-10 06:43:19,707 - root - INFO - Log message 162
# INFO:root:Log message 163
# 2025-07-10 06:43:19,708 - root - INFO - Log message 163
# INFO:root:Log message 164
# 2025-07-10 06:43:19,709 - root - INFO - Log message 164
# INFO:root:Log message 165
# 2025-07-10 06:43:19,711 - root - INFO - Log message 165
# INFO:root:Log message 166
# 2025-07-10 06:43:19,712 - root - INFO - Log message 166
# INFO:root:Log message 167
# 2025-07-10 06:43:19,713 - root - INFO - Log message 167
# INFO:root:Log message 168
# 2025-07-10 06:43:19,715 - root - INFO - Log message 168
# INFO:root:Log message 169
# 2025-07-10 06:43:19,716 - root - INFO - Log message 169
# INFO:root:Log message 170
# 2025-07-10 06:43:19,718 - root - INFO - Log message 170
# INFO:root:Log message 171
# 2025-07-10 06:43:19,719 - root - INFO - Log message 171
# INFO:root:Log message 172
# 2025-07-10 06:43:19,733 - root - INFO - Log message 172
# INFO:root:Log message 173
# 2025-07-10 06:43:19,735 - root - INFO - Log message 173
# INFO:root:Log message 174
# 2025-07-10 06:43:19,737 - root - INFO - Log message 174
# INFO:root:Log message 175
# 2025-07-10 06:43:19,738 - root - INFO - Log message 175
# INFO:root:Log message 176
# 2025-07-10 06:43:19,739 - root - INFO - Log message 176
# INFO:root:Log message 177
# 2025-07-10 06:43:19,740 - root - INFO - Log message 177
# INFO:root:Log message 178
# 2025-07-10 06:43:19,741 - root - INFO - Log message 178
# INFO:root:Log message 179
# 2025-07-10 06:43:19,742 - root - INFO - Log message 179
# INFO:root:Log message 180
# 2025-07-10 06:43:19,745 - root - INFO - Log message 180
# INFO:root:Log message 181
# 2025-07-10 06:43:19,746 - root - INFO - Log message 181
# INFO:root:Log message 182
# 2025-07-10 06:43:19,748 - root - INFO - Log message 182
# INFO:root:Log message 183
# 2025-07-10 06:43:19,752 - root - INFO - Log message 183
# INFO:root:Log message 184
# 2025-07-10 06:43:19,753 - root - INFO - Log message 184
# INFO:root:Log message 185
# 2025-07-10 06:43:19,754 - root - INFO - Log message 185
# INFO:root:Log message 186
# 2025-07-10 06:43:19,755 - root - INFO - Log message 186
# INFO:root:Log message 187
# 2025-07-10 06:43:19,756 - root - INFO - Log message 187
# INFO:root:Log message 188
# 2025-07-10 06:43:19,758 - root - INFO - Log message 188
# INFO:root:Log message 189
# 2025-07-10 06:43:19,767 - root - INFO - Log message 189
# INFO:root:Log message 190
# 2025-07-10 06:43:19,768 - root - INFO - Log message 190
# INFO:root:Log message 191
# 2025-07-10 06:43:19,770 - root - INFO - Log message 191
# INFO:root:Log message 192
# 2025-07-10 06:43:19,772 - root - INFO - Log message 192
# INFO:root:Log message 193
# 2025-07-10 06:43:19,774 - root - INFO - Log message 193
# INFO:root:Log message 194
# 2025-07-10 06:43:19,775 - root - INFO - Log message 194
# INFO:root:Log message 195
# 2025-07-10 06:43:19,777 - root - INFO - Log message 195
# INFO:root:Log message 196
# 2025-07-10 06:43:19,779 - root - INFO - Log message 196
# INFO:root:Log message 197
# 2025-07-10 06:43:19,781 - root - INFO - Log message 197
# INFO:root:Log message 198
# 2025-07-10 06:43:19,783 - root - INFO - Log message 198
# INFO:root:Log message 199
# 2025-07-10 06:43:19,785 - root - INFO - Log message 199
# INFO:root:Log message 200
# 2025-07-10 06:43:19,787 - root - INFO - Log message 200
# INFO:root:Log message 201
# 2025-07-10 06:43:19,789 - root - INFO - Log message 201
# INFO:root:Log message 202
# 2025-07-10 06:43:19,792 - root - INFO - Log message 202
# INFO:root:Log message 203
# 2025-07-10 06:43:19,794 - root - INFO - Log message 203
# INFO:root:Log message 204
# 2025-07-10 06:43:19,796 - root - INFO - Log message 204
# INFO:root:Log message 205
# 2025-07-10 06:43:19,798 - root - INFO - Log message 205
# INFO:root:Log message 206
# 2025-07-10 06:43:19,800 - root - INFO - Log message 206
# INFO:root:Log message 207
# 2025-07-10 06:43:19,803 - root - INFO - Log message 207
# INFO:root:Log message 208
# 2025-07-10 06:43:19,804 - root - INFO - Log message 208
# INFO:root:Log message 209
# 2025-07-10 06:43:19,807 - root - INFO - Log message 209
# INFO:root:Log message 210
# 2025-07-10 06:43:19,809 - root - INFO - Log message 210
# INFO:root:Log message 211
# 2025-07-10 06:43:19,811 - root - INFO - Log message 211
# INFO:root:Log message 212
# 2025-07-10 06:43:19,812 - root - INFO - Log message 212
# INFO:root:Log message 213
# 2025-07-10 06:43:19,814 - root - INFO - Log message 213
# INFO:root:Log message 214
# 2025-07-10 06:43:19,816 - root - INFO - Log message 214
# INFO:root:Log message 215
# 2025-07-10 06:43:19,818 - root - INFO - Log message 215
# INFO:root:Log message 216
# 2025-07-10 06:43:19,819 - root - INFO - Log message 216
# INFO:root:Log message 217
# 2025-07-10 06:43:19,821 - root - INFO - Log message 217
# INFO:root:Log message 218
# 2025-07-10 06:43:19,823 - root - INFO - Log message 218
# INFO:root:Log message 219
# 2025-07-10 06:43:19,824 - root - INFO - Log message 219
# INFO:root:Log message 220
# 2025-07-10 06:43:19,831 - root - INFO - Log message 220
# INFO:root:Log message 221
# 2025-07-10 06:43:19,833 - root - INFO - Log message 221
# INFO:root:Log message 222
# 2025-07-10 06:43:19,835 - root - INFO - Log message 222
# INFO:root:Log message 223
# 2025-07-10 06:43:19,838 - root - INFO - Log message 223
# INFO:root:Log message 224
# 2025-07-10 06:43:19,840 - root - INFO - Log message 224
# INFO:root:Log message 225
# 2025-07-10 06:43:19,842 - root - INFO - Log message 225
# INFO:root:Log message 226
# 2025-07-10 06:43:19,843 - root - INFO - Log message 226
# INFO:root:Log message 227
# 2025-07-10 06:43:19,845 - root - INFO - Log message 227
# INFO:root:Log message 228
# 2025-07-10 06:43:19,848 - root - INFO - Log message 228
# INFO:root:Log message 229
# 2025-07-10 06:43:19,850 - root - INFO - Log message 229
# INFO:root:Log message 230
# 2025-07-10 06:43:19,853 - root - INFO - Log message 230
# INFO:root:Log message 231
# 2025-07-10 06:43:19,855 - root - INFO - Log message 231
# INFO:root:Log message 232
# 2025-07-10 06:43:19,857 - root - INFO - Log message 232
# INFO:root:Log message 233
# 2025-07-10 06:43:19,858 - root - INFO - Log message 233
# INFO:root:Log message 234
# 2025-07-10 06:43:19,859 - root - INFO - Log message 234
# INFO:root:Log message 235
# 2025-07-10 06:43:19,861 - root - INFO - Log message 235
# INFO:root:Log message 236
# 2025-07-10 06:43:19,863 - root - INFO - Log message 236
# INFO:root:Log message 237
# 2025-07-10 06:43:19,864 - root - INFO - Log message 237
# INFO:root:Log message 238
# 2025-07-10 06:43:19,866 - root - INFO - Log message 238
# INFO:root:Log message 239
# 2025-07-10 06:43:19,867 - root - INFO - Log message 239
# INFO:root:Log message 240
# 2025-07-10 06:43:19,869 - root - INFO - Log message 240
# INFO:root:Log message 241
# 2025-07-10 06:43:19,871 - root - INFO - Log message 241
# INFO:root:Log message 242
# 2025-07-10 06:43:19,872 - root - INFO - Log message 242
# INFO:root:Log message 243
# 2025-07-10 06:43:19,873 - root - INFO - Log message 243
# INFO:root:Log message 244
# 2025-07-10 06:43:19,874 - root - INFO - Log message 244
# INFO:root:Log message 245
# 2025-07-10 06:43:19,875 - root - INFO - Log message 245
# INFO:root:Log message 246
# 2025-07-10 06:43:19,876 - root - INFO - Log message 246
# INFO:root:Log message 247
# 2025-07-10 06:43:19,877 - root - INFO - Log message 247
# INFO:root:Log message 248
# 2025-07-10 06:43:19,879 - root - INFO - Log message 248
# INFO:root:Log message 249
# 2025-07-10 06:43:19,880 - root - INFO - Log message 249
# INFO:root:Log message 250
# 2025-07-10 06:43:19,881 - root - INFO - Log message 250
# INFO:root:Log message 251
# 2025-07-10 06:43:19,883 - root - INFO - Log message 251
# INFO:root:Log message 252
# 2025-07-10 06:43:19,884 - root - INFO - Log message 252
# INFO:root:Log message 253
# 2025-07-10 06:43:19,886 - root - INFO - Log message 253
# INFO:root:Log message 254
# 2025-07-10 06:43:19,887 - root - INFO - Log message 254
# INFO:root:Log message 255
# 2025-07-10 06:43:19,888 - root - INFO - Log message 255
# INFO:root:Log message 256
# 2025-07-10 06:43:19,890 - root - INFO - Log message 256
# INFO:root:Log message 257
# 2025-07-10 06:43:19,891 - root - INFO - Log message 257
# INFO:root:Log message 258
# 2025-07-10 06:43:19,893 - root - INFO - Log message 258
# INFO:root:Log message 259
# 2025-07-10 06:43:19,894 - root - INFO - Log message 259
# INFO:root:Log message 260
# 2025-07-10 06:43:19,895 - root - INFO - Log message 260
# INFO:root:Log message 261
# 2025-07-10 06:43:19,897 - root - INFO - Log message 261
# INFO:root:Log message 262
# 2025-07-10 06:43:19,898 - root - INFO - Log message 262
# INFO:root:Log message 263
# 2025-07-10 06:43:19,900 - root - INFO - Log message 263
# INFO:root:Log message 264
# 2025-07-10 06:43:19,901 - root - INFO - Log message 264
# INFO:root:Log message 265
# 2025-07-10 06:43:19,902 - root - INFO - Log message 265
# INFO:root:Log message 266
# 2025-07-10 06:43:19,904 - root - INFO - Log message 266
# INFO:root:Log message 267
# 2025-07-10 06:43:19,905 - root - INFO - Log message 267
# INFO:root:Log message 268
# 2025-07-10 06:43:19,906 - root - INFO - Log message 268
# INFO:root:Log message 269
# 2025-07-10 06:43:19,908 - root - INFO - Log message 269
# INFO:root:Log message 270
# 2025-07-10 06:43:19,909 - root - INFO - Log message 270
# INFO:root:Log message 271
# 2025-07-10 06:43:19,914 - root - INFO - Log message 271
# INFO:root:Log message 272
# 2025-07-10 06:43:19,916 - root - INFO - Log message 272
# INFO:root:Log message 273
# 2025-07-10 06:43:19,917 - root - INFO - Log message 273
# INFO:root:Log message 274
# 2025-07-10 06:43:19,918 - root - INFO - Log message 274
# INFO:root:Log message 275
# 2025-07-10 06:43:19,919 - root - INFO - Log message 275
# INFO:root:Log message 276
# 2025-07-10 06:43:19,920 - root - INFO - Log message 276
# INFO:root:Log message 277
# 2025-07-10 06:43:19,922 - root - INFO - Log message 277
# INFO:root:Log message 278
# 2025-07-10 06:43:19,923 - root - INFO - Log message 278
# INFO:root:Log message 279
# 2025-07-10 06:43:19,924 - root - INFO - Log message 279
# INFO:root:Log message 280
# 2025-07-10 06:43:19,925 - root - INFO - Log message 280
# INFO:root:Log message 281
# 2025-07-10 06:43:19,927 - root - INFO - Log message 281
# INFO:root:Log message 282
# 2025-07-10 06:43:19,929 - root - INFO - Log message 282
# INFO:root:Log message 283
# 2025-07-10 06:43:19,930 - root - INFO - Log message 283
# INFO:root:Log message 284
# 2025-07-10 06:43:19,932 - root - INFO - Log message 284
# INFO:root:Log message 285
# 2025-07-10 06:43:19,933 - root - INFO - Log message 285
# INFO:root:Log message 286
# 2025-07-10 06:43:19,934 - root - INFO - Log message 286
# INFO:root:Log message 287
# 2025-07-10 06:43:19,936 - root - INFO - Log message 287
# INFO:root:Log message 288
# 2025-07-10 06:43:19,937 - root - INFO - Log message 288
# INFO:root:Log message 289
# 2025-07-10 06:43:19,939 - root - INFO - Log message 289
# INFO:root:Log message 290
# 2025-07-10 06:43:19,940 - root - INFO - Log message 290
# INFO:root:Log message 291
# 2025-07-10 06:43:19,941 - root - INFO - Log message 291
# INFO:root:Log message 292
# 2025-07-10 06:43:19,943 - root - INFO - Log message 292
# INFO:root:Log message 293
# 2025-07-10 06:43:19,944 - root - INFO - Log message 293
# INFO:root:Log message 294
# 2025-07-10 06:43:19,945 - root - INFO - Log message 294
# INFO:root:Log message 295
# 2025-07-10 06:43:19,947 - root - INFO - Log message 295
# INFO:root:Log message 296
# 2025-07-10 06:43:19,948 - root - INFO - Log message 296
# INFO:root:Log message 297
# 2025-07-10 06:43:19,950 - root - INFO - Log message 297
# INFO:root:Log message 298
# 2025-07-10 06:43:19,951 - root - INFO - Log message 298
# INFO:root:Log message 299
# 2025-07-10 06:43:19,952 - root - INFO - Log message 299
# INFO:root:Log message 300
# 2025-07-10 06:43:19,954 - root - INFO - Log message 300
# INFO:root:Log message 301
# 2025-07-10 06:43:19,955 - root - INFO - Log message 301
# INFO:root:Log message 302
# 2025-07-10 06:43:19,956 - root - INFO - Log message 302
# INFO:root:Log message 303
# 2025-07-10 06:43:19,957 - root - INFO - Log message 303
# INFO:root:Log message 304
# 2025-07-10 06:43:19,958 - root - INFO - Log message 304
# INFO:root:Log message 305
# 2025-07-10 06:43:19,960 - root - INFO - Log message 305
# INFO:root:Log message 306
# 2025-07-10 06:43:19,961 - root - INFO - Log message 306
# INFO:root:Log message 307
# 2025-07-10 06:43:19,962 - root - INFO - Log message 307
# INFO:root:Log message 308
# 2025-07-10 06:43:19,964 - root - INFO - Log message 308
# INFO:root:Log message 309
# 2025-07-10 06:43:19,965 - root - INFO - Log message 309
# INFO:root:Log message 310
# 2025-07-10 06:43:19,966 - root - INFO - Log message 310
# INFO:root:Log message 311
# 2025-07-10 06:43:19,968 - root - INFO - Log message 311
# INFO:root:Log message 312
# 2025-07-10 06:43:19,969 - root - INFO - Log message 312
# INFO:root:Log message 313
# 2025-07-10 06:43:19,970 - root - INFO - Log message 313
# INFO:root:Log message 314
# 2025-07-10 06:43:19,971 - root - INFO - Log message 314
# INFO:root:Log message 315
# 2025-07-10 06:43:19,972 - root - INFO - Log message 315
# INFO:root:Log message 316
# 2025-07-10 06:43:19,977 - root - INFO - Log message 316
# INFO:root:Log message 317
# 2025-07-10 06:43:19,978 - root - INFO - Log message 317
# INFO:root:Log message 318
# 2025-07-10 06:43:19,979 - root - INFO - Log message 318
# INFO:root:Log message 319
# 2025-07-10 06:43:19,980 - root - INFO - Log message 319
# INFO:root:Log message 320
# 2025-07-10 06:43:19,981 - root - INFO - Log message 320
# INFO:root:Log message 321
# 2025-07-10 06:43:19,982 - root - INFO - Log message 321
# INFO:root:Log message 322
# 2025-07-10 06:43:19,983 - root - INFO - Log message 322
# INFO:root:Log message 323
# 2025-07-10 06:43:19,987 - root - INFO - Log message 323
# INFO:root:Log message 324
# 2025-07-10 06:43:19,988 - root - INFO - Log message 324
# INFO:root:Log message 325
# 2025-07-10 06:43:19,989 - root - INFO - Log message 325
# INFO:root:Log message 326
# 2025-07-10 06:43:19,990 - root - INFO - Log message 326
# INFO:root:Log message 327
# 2025-07-10 06:43:19,994 - root - INFO - Log message 327
# INFO:root:Log message 328
# 2025-07-10 06:43:19,995 - root - INFO - Log message 328
# INFO:root:Log message 329
# 2025-07-10 06:43:19,997 - root - INFO - Log message 329
# INFO:root:Log message 330
# 2025-07-10 06:43:19,998 - root - INFO - Log message 330
# INFO:root:Log message 331
# 2025-07-10 06:43:19,999 - root - INFO - Log message 331
# INFO:root:Log message 332
# 2025-07-10 06:43:20,000 - root - INFO - Log message 332
# INFO:root:Log message 333
# 2025-07-10 06:43:20,001 - root - INFO - Log message 333
# INFO:root:Log message 334
# 2025-07-10 06:43:20,002 - root - INFO - Log message 334
# INFO:root:Log message 335
# 2025-07-10 06:43:20,003 - root - INFO - Log message 335
# INFO:root:Log message 336
# 2025-07-10 06:43:20,004 - root - INFO - Log message 336
# INFO:root:Log message 337
# 2025-07-10 06:43:20,005 - root - INFO - Log message 337
# INFO:root:Log message 338
# 2025-07-10 06:43:20,006 - root - INFO - Log message 338
# INFO:root:Log message 339
# 2025-07-10 06:43:20,006 - root - INFO - Log message 339
# INFO:root:Log message 340
# 2025-07-10 06:43:20,007 - root - INFO - Log message 340
# INFO:root:Log message 341
# 2025-07-10 06:43:20,008 - root - INFO - Log message 341
# INFO:root:Log message 342
# 2025-07-10 06:43:20,009 - root - INFO - Log message 342
# INFO:root:Log message 343
# 2025-07-10 06:43:20,010 - root - INFO - Log message 343
# INFO:root:Log message 344
# 2025-07-10 06:43:20,012 - root - INFO - Log message 344
# INFO:root:Log message 345
# 2025-07-10 06:43:20,015 - root - INFO - Log message 345
# INFO:root:Log message 346
# 2025-07-10 06:43:20,016 - root - INFO - Log message 346
# INFO:root:Log message 347
# 2025-07-10 06:43:20,017 - root - INFO - Log message 347
# INFO:root:Log message 348
# 2025-07-10 06:43:20,018 - root - INFO - Log message 348
# INFO:root:Log message 349
# 2025-07-10 06:43:20,019 - root - INFO - Log message 349
# INFO:root:Log message 350
# 2025-07-10 06:43:20,020 - root - INFO - Log message 350
# INFO:root:Log message 351
# 2025-07-10 06:43:20,021 - root - INFO - Log message 351
# INFO:root:Log message 352
# 2025-07-10 06:43:20,022 - root - INFO - Log message 352
# INFO:root:Log message 353
# 2025-07-10 06:43:20,023 - root - INFO - Log message 353
# INFO:root:Log message 354
# 2025-07-10 06:43:20,027 - root - INFO - Log message 354
# INFO:root:Log message 355
# 2025-07-10 06:43:20,028 - root - INFO - Log message 355
# INFO:root:Log message 356
# 2025-07-10 06:43:20,029 - root - INFO - Log message 356
# INFO:root:Log message 357
# 2025-07-10 06:43:20,030 - root - INFO - Log message 357
# INFO:root:Log message 358
# 2025-07-10 06:43:20,031 - root - INFO - Log message 358
# INFO:root:Log message 359
# 2025-07-10 06:43:20,032 - root - INFO - Log message 359
# INFO:root:Log message 360
# 2025-07-10 06:43:20,033 - root - INFO - Log message 360
# INFO:root:Log message 361
# 2025-07-10 06:43:20,034 - root - INFO - Log message 361
# INFO:root:Log message 362
# 2025-07-10 06:43:20,035 - root - INFO - Log message 362
# INFO:root:Log message 363
# 2025-07-10 06:43:20,036 - root - INFO - Log message 363
# INFO:root:Log message 364
# 2025-07-10 06:43:20,037 - root - INFO - Log message 364
# INFO:root:Log message 365
# 2025-07-10 06:43:20,038 - root - INFO - Log message 365
# INFO:root:Log message 366
# 2025-07-10 06:43:20,039 - root - INFO - Log message 366
# INFO:root:Log message 367
# 2025-07-10 06:43:20,040 - root - INFO - Log message 367
# INFO:root:Log message 368
# 2025-07-10 06:43:20,041 - root - INFO - Log message 368
# INFO:root:Log message 369
# 2025-07-10 06:43:20,042 - root - INFO - Log message 369
# INFO:root:Log message 370
# 2025-07-10 06:43:20,044 - root - INFO - Log message 370
# INFO:root:Log message 371
# 2025-07-10 06:43:20,044 - root - INFO - Log message 371
# INFO:root:Log message 372
# 2025-07-10 06:43:20,045 - root - INFO - Log message 372
# INFO:root:Log message 373
# 2025-07-10 06:43:20,046 - root - INFO - Log message 373
# INFO:root:Log message 374
# 2025-07-10 06:43:20,047 - root - INFO - Log message 374
# INFO:root:Log message 375
# 2025-07-10 06:43:20,048 - root - INFO - Log message 375
# INFO:root:Log message 376
# 2025-07-10 06:43:20,050 - root - INFO - Log message 376
# INFO:root:Log message 377
# 2025-07-10 06:43:20,051 - root - INFO - Log message 377
# INFO:root:Log message 378
# 2025-07-10 06:43:20,052 - root - INFO - Log message 378
# INFO:root:Log message 379
# 2025-07-10 06:43:20,053 - root - INFO - Log message 379
# INFO:root:Log message 380
# 2025-07-10 06:43:20,054 - root - INFO - Log message 380
# INFO:root:Log message 381
# 2025-07-10 06:43:20,055 - root - INFO - Log message 381
# INFO:root:Log message 382
# 2025-07-10 06:43:20,056 - root - INFO - Log message 382
# INFO:root:Log message 383
# 2025-07-10 06:43:20,057 - root - INFO - Log message 383
# INFO:root:Log message 384
# 2025-07-10 06:43:20,058 - root - INFO - Log message 384
# INFO:root:Log message 385
# 2025-07-10 06:43:20,059 - root - INFO - Log message 385
# INFO:root:Log message 386
# 2025-07-10 06:43:20,060 - root - INFO - Log message 386
# INFO:root:Log message 387
# 2025-07-10 06:43:20,062 - root - INFO - Log message 387
# INFO:root:Log message 388
# 2025-07-10 06:43:20,063 - root - INFO - Log message 388
# INFO:root:Log message 389
# 2025-07-10 06:43:20,064 - root - INFO - Log message 389
# INFO:root:Log message 390
# 2025-07-10 06:43:20,068 - root - INFO - Log message 390
# INFO:root:Log message 391
# 2025-07-10 06:43:20,069 - root - INFO - Log message 391
# INFO:root:Log message 392
# 2025-07-10 06:43:20,070 - root - INFO - Log message 392
# INFO:root:Log message 393
# 2025-07-10 06:43:20,071 - root - INFO - Log message 393
# INFO:root:Log message 394
# 2025-07-10 06:43:20,071 - root - INFO - Log message 394
# INFO:root:Log message 395
# 2025-07-10 06:43:20,073 - root - INFO - Log message 395
# INFO:root:Log message 396
# 2025-07-10 06:43:20,074 - root - INFO - Log message 396
# INFO:root:Log message 397
# 2025-07-10 06:43:20,075 - root - INFO - Log message 397
# INFO:root:Log message 398
# 2025-07-10 06:43:20,076 - root - INFO - Log message 398
# INFO:root:Log message 399
# 2025-07-10 06:43:20,077 - root - INFO - Log message 399
# INFO:root:Log message 400
# 2025-07-10 06:43:20,078 - root - INFO - Log message 400
# INFO:root:Log message 401
# 2025-07-10 06:43:20,079 - root - INFO - Log message 401
# INFO:root:Log message 402
# 2025-07-10 06:43:20,080 - root - INFO - Log message 402
# INFO:root:Log message 403
# 2025-07-10 06:43:20,081 - root - INFO - Log message 403
# INFO:root:Log message 404
# 2025-07-10 06:43:20,082 - root - INFO - Log message 404
# INFO:root:Log message 405
# 2025-07-10 06:43:20,083 - root - INFO - Log message 405
# INFO:root:Log message 406
# 2025-07-10 06:43:20,084 - root - INFO - Log message 406
# INFO:root:Log message 407
# 2025-07-10 06:43:20,086 - root - INFO - Log message 407
# INFO:root:Log message 408
# 2025-07-10 06:43:20,087 - root - INFO - Log message 408
# INFO:root:Log message 409
# 2025-07-10 06:43:20,088 - root - INFO - Log message 409
# INFO:root:Log message 410
# 2025-07-10 06:43:20,090 - root - INFO - Log message 410
# INFO:root:Log message 411
# 2025-07-10 06:43:20,091 - root - INFO - Log message 411
# INFO:root:Log message 412
# 2025-07-10 06:43:20,092 - root - INFO - Log message 412
# INFO:root:Log message 413
# 2025-07-10 06:43:20,093 - root - INFO - Log message 413
# INFO:root:Log message 414
# 2025-07-10 06:43:20,094 - root - INFO - Log message 414
# INFO:root:Log message 415
# 2025-07-10 06:43:20,098 - root - INFO - Log message 415
# INFO:root:Log message 416
# 2025-07-10 06:43:20,099 - root - INFO - Log message 416
# INFO:root:Log message 417
# 2025-07-10 06:43:20,100 - root - INFO - Log message 417
# INFO:root:Log message 418
# 2025-07-10 06:43:20,103 - root - INFO - Log message 418
# INFO:root:Log message 419
# 2025-07-10 06:43:20,104 - root - INFO - Log message 419
# INFO:root:Log message 420
# 2025-07-10 06:43:20,106 - root - INFO - Log message 420
# INFO:root:Log message 421
# 2025-07-10 06:43:20,107 - root - INFO - Log message 421
# INFO:root:Log message 422
# 2025-07-10 06:43:20,108 - root - INFO - Log message 422
# INFO:root:Log message 423
# 2025-07-10 06:43:20,109 - root - INFO - Log message 423
# INFO:root:Log message 424
# 2025-07-10 06:43:20,112 - root - INFO - Log message 424
# INFO:root:Log message 425
# 2025-07-10 06:43:20,113 - root - INFO - Log message 425
# INFO:root:Log message 426
# 2025-07-10 06:43:20,114 - root - INFO - Log message 426
# INFO:root:Log message 427
# 2025-07-10 06:43:20,115 - root - INFO - Log message 427
# INFO:root:Log message 428
# 2025-07-10 06:43:20,116 - root - INFO - Log message 428
# INFO:root:Log message 429
# 2025-07-10 06:43:20,117 - root - INFO - Log message 429
# INFO:root:Log message 430
# 2025-07-10 06:43:20,121 - root - INFO - Log message 430
# INFO:root:Log message 431
# 2025-07-10 06:43:20,122 - root - INFO - Log message 431
# INFO:root:Log message 432
# 2025-07-10 06:43:20,123 - root - INFO - Log message 432
# INFO:root:Log message 433
# 2025-07-10 06:43:20,125 - root - INFO - Log message 433
# INFO:root:Log message 434
# 2025-07-10 06:43:20,126 - root - INFO - Log message 434
# INFO:root:Log message 435
# 2025-07-10 06:43:20,128 - root - INFO - Log message 435
# INFO:root:Log message 436
# 2025-07-10 06:43:20,129 - root - INFO - Log message 436
# INFO:root:Log message 437
# 2025-07-10 06:43:20,130 - root - INFO - Log message 437
# INFO:root:Log message 438
# 2025-07-10 06:43:20,131 - root - INFO - Log message 438
# INFO:root:Log message 439
# 2025-07-10 06:43:20,132 - root - INFO - Log message 439
# INFO:root:Log message 440
# 2025-07-10 06:43:20,136 - root - INFO - Log message 440
# INFO:root:Log message 441
# 2025-07-10 06:43:20,138 - root - INFO - Log message 441
# INFO:root:Log message 442
# 2025-07-10 06:43:20,139 - root - INFO - Log message 442
# INFO:root:Log message 443
# 2025-07-10 06:43:20,140 - root - INFO - Log message 443
# INFO:root:Log message 444
# 2025-07-10 06:43:20,141 - root - INFO - Log message 444
# INFO:root:Log message 445
# 2025-07-10 06:43:20,143 - root - INFO - Log message 445
# INFO:root:Log message 446
# 2025-07-10 06:43:20,144 - root - INFO - Log message 446
# INFO:root:Log message 447
# 2025-07-10 06:43:20,145 - root - INFO - Log message 447
# INFO:root:Log message 448
# 2025-07-10 06:43:20,146 - root - INFO - Log message 448
# INFO:root:Log message 449
# 2025-07-10 06:43:20,147 - root - INFO - Log message 449
# INFO:root:Log message 450
# 2025-07-10 06:43:20,148 - root - INFO - Log message 450
# INFO:root:Log message 451
# 2025-07-10 06:43:20,150 - root - INFO - Log message 451
# INFO:root:Log message 452
# 2025-07-10 06:43:20,151 - root - INFO - Log message 452
# INFO:root:Log message 453
# 2025-07-10 06:43:20,152 - root - INFO - Log message 453
# INFO:root:Log message 454
# 2025-07-10 06:43:20,153 - root - INFO - Log message 454
# INFO:root:Log message 455
# 2025-07-10 06:43:20,154 - root - INFO - Log message 455
# INFO:root:Log message 456
# 2025-07-10 06:43:20,156 - root - INFO - Log message 456
# INFO:root:Log message 457
# 2025-07-10 06:43:20,157 - root - INFO - Log message 457
# INFO:root:Log message 458
# 2025-07-10 06:43:20,158 - root - INFO - Log message 458
# INFO:root:Log message 459
# 2025-07-10 06:43:20,159 - root - INFO - Log message 459
# INFO:root:Log message 460
# 2025-07-10 06:43:20,160 - root - INFO - Log message 460
# INFO:root:Log message 461
# 2025-07-10 06:43:20,161 - root - INFO - Log message 461
# INFO:root:Log message 462
# 2025-07-10 06:43:20,162 - root - INFO - Log message 462
# INFO:root:Log message 463
# 2025-07-10 06:43:20,163 - root - INFO - Log message 463
# INFO:root:Log message 464
# 2025-07-10 06:43:20,165 - root - INFO - Log message 464
# INFO:root:Log message 465
# 2025-07-10 06:43:20,166 - root - INFO - Log message 465
# INFO:root:Log message 466
# 2025-07-10 06:43:20,167 - root - INFO - Log message 466
# INFO:root:Log message 467
# 2025-07-10 06:43:20,168 - root - INFO - Log message 467
# INFO:root:Log message 468
# 2025-07-10 06:43:20,169 - root - INFO - Log message 468
# INFO:root:Log message 469
# 2025-07-10 06:43:20,170 - root - INFO - Log message 469
# INFO:root:Log message 470
# 2025-07-10 06:43:20,172 - root - INFO - Log message 470
# INFO:root:Log message 471
# 2025-07-10 06:43:20,173 - root - INFO - Log message 471
# INFO:root:Log message 472
# 2025-07-10 06:43:20,174 - root - INFO - Log message 472
# INFO:root:Log message 473
# 2025-07-10 06:43:20,175 - root - INFO - Log message 473
# INFO:root:Log message 474
# 2025-07-10 06:43:20,176 - root - INFO - Log message 474
# INFO:root:Log message 475
# 2025-07-10 06:43:20,177 - root - INFO - Log message 475
# INFO:root:Log message 476
# 2025-07-10 06:43:20,179 - root - INFO - Log message 476
# INFO:root:Log message 477
# 2025-07-10 06:43:20,180 - root - INFO - Log message 477
# INFO:root:Log message 478
# 2025-07-10 06:43:20,181 - root - INFO - Log message 478
# INFO:root:Log message 479
# 2025-07-10 06:43:20,182 - root - INFO - Log message 479
# INFO:root:Log message 480
# 2025-07-10 06:43:20,183 - root - INFO - Log message 480
# INFO:root:Log message 481
# 2025-07-10 06:43:20,184 - root - INFO - Log message 481
# INFO:root:Log message 482
# 2025-07-10 06:43:20,186 - root - INFO - Log message 482
# INFO:root:Log message 483
# 2025-07-10 06:43:20,187 - root - INFO - Log message 483
# INFO:root:Log message 484
# 2025-07-10 06:43:20,188 - root - INFO - Log message 484
# INFO:root:Log message 485
# 2025-07-10 06:43:20,189 - root - INFO - Log message 485
# INFO:root:Log message 486
# 2025-07-10 06:43:20,190 - root - INFO - Log message 486
# INFO:root:Log message 487
# 2025-07-10 06:43:20,191 - root - INFO - Log message 487
# INFO:root:Log message 488
# 2025-07-10 06:43:20,193 - root - INFO - Log message 488
# INFO:root:Log message 489
# 2025-07-10 06:43:20,193 - root - INFO - Log message 489
# INFO:root:Log message 490
# 2025-07-10 06:43:20,194 - root - INFO - Log message 490
# INFO:root:Log message 491
# 2025-07-10 06:43:20,196 - root - INFO - Log message 491
# INFO:root:Log message 492
# 2025-07-10 06:43:20,197 - root - INFO - Log message 492
# INFO:root:Log message 493
# 2025-07-10 06:43:20,198 - root - INFO - Log message 493
# INFO:root:Log message 494
# 2025-07-10 06:43:20,199 - root - INFO - Log message 494
# INFO:root:Log message 495
# 2025-07-10 06:43:20,200 - root - INFO - Log message 495
# INFO:root:Log message 496
# 2025-07-10 06:43:20,201 - root - INFO - Log message 496
# INFO:root:Log message 497
# 2025-07-10 06:43:20,202 - root - INFO - Log message 497
# INFO:root:Log message 498
# 2025-07-10 06:43:20,204 - root - INFO - Log message 498
# INFO:root:Log message 499
# 2025-07-10 06:43:20,205 - root - INFO - Log message 499
# INFO:root:Log message 500
# 2025-07-10 06:43:20,206 - root - INFO - Log message 500
# INFO:root:Log message 501
# 2025-07-10 06:43:20,207 - root - INFO - Log message 501
# INFO:root:Log message 502
# 2025-07-10 06:43:20,208 - root - INFO - Log message 502
# INFO:root:Log message 503
# 2025-07-10 06:43:20,209 - root - INFO - Log message 503
# INFO:root:Log message 504
# 2025-07-10 06:43:20,210 - root - INFO - Log message 504
# INFO:root:Log message 505
# 2025-07-10 06:43:20,211 - root - INFO - Log message 505
# INFO:root:Log message 506
# 2025-07-10 06:43:20,213 - root - INFO - Log message 506
# INFO:root:Log message 507
# 2025-07-10 06:43:20,214 - root - INFO - Log message 507
# INFO:root:Log message 508
# 2025-07-10 06:43:20,215 - root - INFO - Log message 508
# INFO:root:Log message 509
# 2025-07-10 06:43:20,216 - root - INFO - Log message 509
# INFO:root:Log message 510
# 2025-07-10 06:43:20,217 - root - INFO - Log message 510
# INFO:root:Log message 511
# 2025-07-10 06:43:20,218 - root - INFO - Log message 511
# INFO:root:Log message 512
# 2025-07-10 06:43:20,219 - root - INFO - Log message 512
# INFO:root:Log message 513
# 2025-07-10 06:43:20,220 - root - INFO - Log message 513
# INFO:root:Log message 514
# 2025-07-10 06:43:20,221 - root - INFO - Log message 514
# INFO:root:Log message 515
# 2025-07-10 06:43:20,223 - root - INFO - Log message 515
# INFO:root:Log message 516
# 2025-07-10 06:43:20,224 - root - INFO - Log message 516
# INFO:root:Log message 517
# 2025-07-10 06:43:20,225 - root - INFO - Log message 517
# INFO:root:Log message 518
# 2025-07-10 06:43:20,226 - root - INFO - Log message 518
# INFO:root:Log message 519
# 2025-07-10 06:43:20,227 - root - INFO - Log message 519
# INFO:root:Log message 520
# 2025-07-10 06:43:20,228 - root - INFO - Log message 520
# INFO:root:Log message 521
# 2025-07-10 06:43:20,229 - root - INFO - Log message 521
# INFO:root:Log message 522
# 2025-07-10 06:43:20,231 - root - INFO - Log message 522
# INFO:root:Log message 523
# 2025-07-10 06:43:20,232 - root - INFO - Log message 523
# INFO:root:Log message 524
# 2025-07-10 06:43:20,233 - root - INFO - Log message 524
# INFO:root:Log message 525
# 2025-07-10 06:43:20,234 - root - INFO - Log message 525
# INFO:root:Log message 526
# 2025-07-10 06:43:20,235 - root - INFO - Log message 526
# INFO:root:Log message 527
# 2025-07-10 06:43:20,236 - root - INFO - Log message 527
# INFO:root:Log message 528
# 2025-07-10 06:43:20,237 - root - INFO - Log message 528
# INFO:root:Log message 529
# 2025-07-10 06:43:20,238 - root - INFO - Log message 529
# INFO:root:Log message 530
# 2025-07-10 06:43:20,239 - root - INFO - Log message 530
# INFO:root:Log message 531
# 2025-07-10 06:43:20,241 - root - INFO - Log message 531
# INFO:root:Log message 532
# 2025-07-10 06:43:20,242 - root - INFO - Log message 532
# INFO:root:Log message 533
# 2025-07-10 06:43:20,243 - root - INFO - Log message 533
# INFO:root:Log message 534
# 2025-07-10 06:43:20,244 - root - INFO - Log message 534
# INFO:root:Log message 535
# 2025-07-10 06:43:20,245 - root - INFO - Log message 535
# INFO:root:Log message 536
# 2025-07-10 06:43:20,246 - root - INFO - Log message 536
# INFO:root:Log message 537
# 2025-07-10 06:43:20,247 - root - INFO - Log message 537
# INFO:root:Log message 538
# 2025-07-10 06:43:20,248 - root - INFO - Log message 538
# INFO:root:Log message 539
# 2025-07-10 06:43:20,249 - root - INFO - Log message 539
# INFO:root:Log message 540
# 2025-07-10 06:43:20,250 - root - INFO - Log message 540
# INFO:root:Log message 541
# 2025-07-10 06:43:20,251 - root - INFO - Log message 541
# INFO:root:Log message 542
# 2025-07-10 06:43:20,252 - root - INFO - Log message 542
# INFO:root:Log message 543
# 2025-07-10 06:43:20,253 - root - INFO - Log message 543
# INFO:root:Log message 544
# 2025-07-10 06:43:20,255 - root - INFO - Log message 544
# INFO:root:Log message 545
# 2025-07-10 06:43:20,256 - root - INFO - Log message 545
# INFO:root:Log message 546
# 2025-07-10 06:43:20,257 - root - INFO - Log message 546
# INFO:root:Log message 547
# 2025-07-10 06:43:20,258 - root - INFO - Log message 547
# INFO:root:Log message 548
# 2025-07-10 06:43:20,259 - root - INFO - Log message 548
# INFO:root:Log message 549
# 2025-07-10 06:43:20,260 - root - INFO - Log message 549
# INFO:root:Log message 550
# 2025-07-10 06:43:20,261 - root - INFO - Log message 550
# INFO:root:Log message 551
# 2025-07-10 06:43:20,262 - root - INFO - Log message 551
# INFO:root:Log message 552
# 2025-07-10 06:43:20,264 - root - INFO - Log message 552
# INFO:root:Log message 553
# 2025-07-10 06:43:20,265 - root - INFO - Log message 553
# INFO:root:Log message 554
# 2025-07-10 06:43:20,266 - root - INFO - Log message 554
# INFO:root:Log message 555
# 2025-07-10 06:43:20,267 - root - INFO - Log message 555
# INFO:root:Log message 556
# 2025-07-10 06:43:20,268 - root - INFO - Log message 556
# INFO:root:Log message 557
# 2025-07-10 06:43:20,269 - root - INFO - Log message 557
# INFO:root:Log message 558
# 2025-07-10 06:43:20,270 - root - INFO - Log message 558
# INFO:root:Log message 559
# 2025-07-10 06:43:20,271 - root - INFO - Log message 559
# INFO:root:Log message 560
# 2025-07-10 06:43:20,272 - root - INFO - Log message 560
# INFO:root:Log message 561
# 2025-07-10 06:43:20,273 - root - INFO - Log message 561
# INFO:root:Log message 562
# 2025-07-10 06:43:20,274 - root - INFO - Log message 562
# INFO:root:Log message 563
# 2025-07-10 06:43:20,276 - root - INFO - Log message 563
# INFO:root:Log message 564
# 2025-07-10 06:43:20,277 - root - INFO - Log message 564
# INFO:root:Log message 565
# 2025-07-10 06:43:20,278 - root - INFO - Log message 565
# INFO:root:Log message 566
# 2025-07-10 06:43:20,279 - root - INFO - Log message 566
# INFO:root:Log message 567
# 2025-07-10 06:43:20,280 - root - INFO - Log message 567
# INFO:root:Log message 568
# 2025-07-10 06:43:20,281 - root - INFO - Log message 568
# INFO:root:Log message 569
# 2025-07-10 06:43:20,282 - root - INFO - Log message 569
# INFO:root:Log message 570
# 2025-07-10 06:43:20,283 - root - INFO - Log message 570
# INFO:root:Log message 571
# 2025-07-10 06:43:20,284 - root - INFO - Log message 571
# INFO:root:Log message 572
# 2025-07-10 06:43:20,285 - root - INFO - Log message 572
# INFO:root:Log message 573
# 2025-07-10 06:43:20,286 - root - INFO - Log message 573
# INFO:root:Log message 574
# 2025-07-10 06:43:20,287 - root - INFO - Log message 574
# INFO:root:Log message 575
# 2025-07-10 06:43:20,288 - root - INFO - Log message 575
# INFO:root:Log message 576
# 2025-07-10 06:43:20,289 - root - INFO - Log message 576
# INFO:root:Log message 577
# 2025-07-10 06:43:20,291 - root - INFO - Log message 577
# INFO:root:Log message 578
# 2025-07-10 06:43:20,292 - root - INFO - Log message 578
# INFO:root:Log message 579
# 2025-07-10 06:43:20,293 - root - INFO - Log message 579
# INFO:root:Log message 580
# 2025-07-10 06:43:20,294 - root - INFO - Log message 580
# INFO:root:Log message 581
# ...
# INFO:root:Log message 805
# 2025-07-10 06:43:20,547 - root - INFO - Log message 805
# INFO:root:Log message 806
# 2025-07-10 06:43:20,548 - root - INFO - Log message 806
# INFO:root:Log message 807
# 2025-07-10 06:43:20,549 - root - INFO - Log message 807
# INFO:root:Log message 808
# 2025-07-10 06:43:20,549 - root - INFO - Log message 808
# INFO:root:Log message 809
# 2025-07-10 06:43:20,550 - root - INFO - Log message 809
# INFO:root:Log message 810
# 2025-07-10 06:43:20,551 - root - INFO - Log message 810
# INFO:root:Log message 811
# 2025-07-10 06:43:20,552 - root - INFO - Log message 811
# INFO:root:Log message 812
# 2025-07-10 06:43:20,553 - root - INFO - Log message 812
# INFO:root:Log message 813
# 2025-07-10 06:43:20,554 - root - INFO - Log message 813
# INFO:root:Log message 814
# 2025-07-10 06:43:20,555 - root - INFO - Log message 814
# INFO:root:Log message 815
# 2025-07-10 06:43:20,556 - root - INFO - Log message 815
# INFO:root:Log message 816
# 2025-07-10 06:43:20,557 - root - INFO - Log message 816
# INFO:root:Log message 817
# 2025-07-10 06:43:20,558 - root - INFO - Log message 817
# INFO:root:Log message 818
# 2025-07-10 06:43:20,559 - root - INFO - Log message 818
# INFO:root:Log message 819
# 2025-07-10 06:43:20,560 - root - INFO - Log message 819
# INFO:root:Log message 820
# 2025-07-10 06:43:20,561 - root - INFO - Log message 820
# INFO:root:Log message 821
# 2025-07-10 06:43:20,562 - root - INFO - Log message 821
# INFO:root:Log message 822
# 2025-07-10 06:43:20,563 - root - INFO - Log message 822
# INFO:root:Log message 823
# 2025-07-10 06:43:20,565 - root - INFO - Log message 823
# INFO:root:Log message 824
# 2025-07-10 06:43:20,566 - root - INFO - Log message 824
# INFO:root:Log message 825
# 2025-07-10 06:43:20,567 - root - INFO - Log message 825
# INFO:root:Log message 826
# 2025-07-10 06:43:20,568 - root - INFO - Log message 826
# INFO:root:Log message 827
# 2025-07-10 06:43:20,569 - root - INFO - Log message 827
# INFO:root:Log message 828
# 2025-07-10 06:43:20,570 - root - INFO - Log message 828
# INFO:root:Log message 829
# 2025-07-10 06:43:20,571 - root - INFO - Log message 829
# INFO:root:Log message 830
# 2025-07-10 06:43:20,572 - root - INFO - Log message 830
# INFO:root:Log message 831
# 2025-07-10 06:43:20,573 - root - INFO - Log message 831
# INFO:root:Log message 832
# 2025-07-10 06:43:20,574 - root - INFO - Log message 832
# INFO:root:Log message 833
# 2025-07-10 06:43:20,575 - root - INFO - Log message 833
# INFO:root:Log message 834
# 2025-07-10 06:43:20,576 - root - INFO - Log message 834
# INFO:root:Log message 835
# 2025-07-10 06:43:20,577 - root - INFO - Log message 835
# INFO:root:Log message 836
# 2025-07-10 06:43:20,578 - root - INFO - Log message 836
# INFO:root:Log message 837
# 2025-07-10 06:43:20,579 - root - INFO - Log message 837
# INFO:root:Log message 838
# 2025-07-10 06:43:20,580 - root - INFO - Log message 838
# INFO:root:Log message 839
# 2025-07-10 06:43:20,581 - root - INFO - Log message 839
# INFO:root:Log message 840
# 2025-07-10 06:43:20,582 - root - INFO - Log message 840
# INFO:root:Log message 841
# 2025-07-10 06:43:20,584 - root - INFO - Log message 841
# INFO:root:Log message 842
# 2025-07-10 06:43:20,585 - root - INFO - Log message 842
# INFO:root:Log message 843
# 2025-07-10 06:43:20,586 - root - INFO - Log message 843
# INFO:root:Log message 844
# 2025-07-10 06:43:20,587 - root - INFO - Log message 844
# INFO:root:Log message 845
# 2025-07-10 06:43:20,588 - root - INFO - Log message 845
# INFO:root:Log message 846
# 2025-07-10 06:43:20,589 - root - INFO - Log message 846
# INFO:root:Log message 847
# 2025-07-10 06:43:20,590 - root - INFO - Log message 847
# INFO:root:Log message 848
# 2025-07-10 06:43:20,591 - root - INFO - Log message 848
# INFO:root:Log message 849
# 2025-07-10 06:43:20,592 - root - INFO - Log message 849
# INFO:root:Log message 850
# 2025-07-10 06:43:20,592 - root - INFO - Log message 850
# INFO:root:Log message 851
# 2025-07-10 06:43:20,594 - root - INFO - Log message 851
# INFO:root:Log message 852
# 2025-07-10 06:43:20,595 - root - INFO - Log message 852
# INFO:root:Log message 853
# 2025-07-10 06:43:20,596 - root - INFO - Log message 853
# INFO:root:Log message 854
# 2025-07-10 06:43:20,597 - root - INFO - Log message 854
# INFO:root:Log message 855
# 2025-07-10 06:43:20,598 - root - INFO - Log message 855
# INFO:root:Log message 856
# 2025-07-10 06:43:20,599 - root - INFO - Log message 856
# INFO:root:Log message 857
# 2025-07-10 06:43:20,600 - root - INFO - Log message 857
# INFO:root:Log message 858
# 2025-07-10 06:43:20,601 - root - INFO - Log message 858
# INFO:root:Log message 859
# 2025-07-10 06:43:20,602 - root - INFO - Log message 859
# INFO:root:Log message 860
# 2025-07-10 06:43:20,603 - root - INFO - Log message 860
# INFO:root:Log message 861
# 2025-07-10 06:43:20,604 - root - INFO - Log message 861
# INFO:root:Log message 862
# 2025-07-10 06:43:20,605 - root - INFO - Log message 862
# INFO:root:Log message 863
# 2025-07-10 06:43:20,606 - root - INFO - Log message 863
# INFO:root:Log message 864
# 2025-07-10 06:43:20,607 - root - INFO - Log message 864
# INFO:root:Log message 865
# 2025-07-10 06:43:20,609 - root - INFO - Log message 865
# INFO:root:Log message 866
# 2025-07-10 06:43:20,610 - root - INFO - Log message 866
# INFO:root:Log message 867
# 2025-07-10 06:43:20,611 - root - INFO - Log message 867
# INFO:root:Log message 868
# 2025-07-10 06:43:20,612 - root - INFO - Log message 868
# INFO:root:Log message 869
# 2025-07-10 06:43:20,613 - root - INFO - Log message 869
# INFO:root:Log message 870
# 2025-07-10 06:43:20,614 - root - INFO - Log message 870
# INFO:root:Log message 871
# 2025-07-10 06:43:20,615 - root - INFO - Log message 871
# INFO:root:Log message 872
# 2025-07-10 06:43:20,616 - root - INFO - Log message 872
# INFO:root:Log message 873
# 2025-07-10 06:43:20,617 - root - INFO - Log message 873
# INFO:root:Log message 874
# 2025-07-10 06:43:20,618 - root - INFO - Log message 874
# INFO:root:Log message 875
# 2025-07-10 06:43:20,619 - root - INFO - Log message 875
# INFO:root:Log message 876
# 2025-07-10 06:43:20,620 - root - INFO - Log message 876
# INFO:root:Log message 877
# 2025-07-10 06:43:20,621 - root - INFO - Log message 877
# INFO:root:Log message 878
# 2025-07-10 06:43:20,622 - root - INFO - Log message 878
# INFO:root:Log message 879
# 2025-07-10 06:43:20,623 - root - INFO - Log message 879
# INFO:root:Log message 880
# 2025-07-10 06:43:20,624 - root - INFO - Log message 880
# INFO:root:Log message 881
# 2025-07-10 06:43:20,625 - root - INFO - Log message 881
# INFO:root:Log message 882
# 2025-07-10 06:43:20,626 - root - INFO - Log message 882
# INFO:root:Log message 883
# 2025-07-10 06:43:20,629 - root - INFO - Log message 883
# INFO:root:Log message 884
# 2025-07-10 06:43:20,630 - root - INFO - Log message 884
# INFO:root:Log message 885
# 2025-07-10 06:43:20,631 - root - INFO - Log message 885
# INFO:root:Log message 886
# 2025-07-10 06:43:20,632 - root - INFO - Log message 886
# INFO:root:Log message 887
# 2025-07-10 06:43:20,633 - root - INFO - Log message 887
# INFO:root:Log message 888
# 2025-07-10 06:43:20,634 - root - INFO - Log message 888
# INFO:root:Log message 889
# 2025-07-10 06:43:20,635 - root - INFO - Log message 889
# INFO:root:Log message 890
# 2025-07-10 06:43:20,636 - root - INFO - Log message 890
# INFO:root:Log message 891
# 2025-07-10 06:43:20,637 - root - INFO - Log message 891
# INFO:root:Log message 892
# 2025-07-10 06:43:20,638 - root - INFO - Log message 892
# INFO:root:Log message 893
# 2025-07-10 06:43:20,642 - root - INFO - Log message 893
# INFO:root:Log message 894
# 2025-07-10 06:43:20,643 - root - INFO - Log message 894
# INFO:root:Log message 895
# 2025-07-10 06:43:20,644 - root - INFO - Log message 895
# INFO:root:Log message 896
# 2025-07-10 06:43:20,645 - root - INFO - Log message 896
# INFO:root:Log message 897
# 2025-07-10 06:43:20,646 - root - INFO - Log message 897
# INFO:root:Log message 898
# 2025-07-10 06:43:20,647 - root - INFO - Log message 898
# INFO:root:Log message 899
# 2025-07-10 06:43:20,648 - root - INFO - Log message 899
# INFO:root:Log message 900
# 2025-07-10 06:43:20,648 - root - INFO - Log message 900
# INFO:root:Log message 901
# 2025-07-10 06:43:20,649 - root - INFO - Log message 901
# INFO:root:Log message 902
# 2025-07-10 06:43:20,650 - root - INFO - Log message 902
# INFO:root:Log message 903
# 2025-07-10 06:43:20,651 - root - INFO - Log message 903
# INFO:root:Log message 904
# 2025-07-10 06:43:20,652 - root - INFO - Log message 904
# INFO:root:Log message 905
# 2025-07-10 06:43:20,653 - root - INFO - Log message 905
# INFO:root:Log message 906
# 2025-07-10 06:43:20,654 - root - INFO - Log message 906
# INFO:root:Log message 907
# 2025-07-10 06:43:20,654 - root - INFO - Log message 907
# INFO:root:Log message 908
# 2025-07-10 06:43:20,655 - root - INFO - Log message 908
# INFO:root:Log message 909
# 2025-07-10 06:43:20,656 - root - INFO - Log message 909
# INFO:root:Log message 910
# 2025-07-10 06:43:20,657 - root - INFO - Log message 910
# INFO:root:Log message 911
# 2025-07-10 06:43:20,658 - root - INFO - Log message 911
# INFO:root:Log message 912
# 2025-07-10 06:43:20,659 - root - INFO - Log message 912
# INFO:root:Log message 913
# 2025-07-10 06:43:20,660 - root - INFO - Log message 913
# INFO:root:Log message 914
# 2025-07-10 06:43:20,661 - root - INFO - Log message 914
# INFO:root:Log message 915
# 2025-07-10 06:43:20,662 - root - INFO - Log message 915
# INFO:root:Log message 916
# 2025-07-10 06:43:20,663 - root - INFO - Log message 916
# INFO:root:Log message 917
# 2025-07-10 06:43:20,664 - root - INFO - Log message 917
# INFO:root:Log message 918
# 2025-07-10 06:43:20,665 - root - INFO - Log message 918
# INFO:root:Log message 919
# 2025-07-10 06:43:20,666 - root - INFO - Log message 919
# INFO:root:Log message 920
# 2025-07-10 06:43:20,667 - root - INFO - Log message 920
# INFO:root:Log message 921
# 2025-07-10 06:43:20,668 - root - INFO - Log message 921
# INFO:root:Log message 922
# 2025-07-10 06:43:20,669 - root - INFO - Log message 922
# INFO:root:Log message 923
# 2025-07-10 06:43:20,670 - root - INFO - Log message 923
# INFO:root:Log message 924
# 2025-07-10 06:43:20,671 - root - INFO - Log message 924
# INFO:root:Log message 925
# 2025-07-10 06:43:20,672 - root - INFO - Log message 925
# INFO:root:Log message 926
# 2025-07-10 06:43:20,673 - root - INFO - Log message 926
# INFO:root:Log message 927
# 2025-07-10 06:43:20,674 - root - INFO - Log message 927
# INFO:root:Log message 928
# 2025-07-10 06:43:20,675 - root - INFO - Log message 928
# INFO:root:Log message 929
# 2025-07-10 06:43:20,676 - root - INFO - Log message 929
# INFO:root:Log message 930
# 2025-07-10 06:43:20,677 - root - INFO - Log message 930
# INFO:root:Log message 931
# 2025-07-10 06:43:20,677 - root - INFO - Log message 931
# INFO:root:Log message 932
# 2025-07-10 06:43:20,678 - root - INFO - Log message 932
# INFO:root:Log message 933
# 2025-07-10 06:43:20,679 - root - INFO - Log message 933
# INFO:root:Log message 934
# 2025-07-10 06:43:20,680 - root - INFO - Log message 934
# INFO:root:Log message 935
# 2025-07-10 06:43:20,681 - root - INFO - Log message 935
# INFO:root:Log message 936
# 2025-07-10 06:43:20,682 - root - INFO - Log message 936
# INFO:root:Log message 937
# 2025-07-10 06:43:20,683 - root - INFO - Log message 937
# INFO:root:Log message 938
# 2025-07-10 06:43:20,684 - root - INFO - Log message 938
# INFO:root:Log message 939
# 2025-07-10 06:43:20,685 - root - INFO - Log message 939
# INFO:root:Log message 940
# 2025-07-10 06:43:20,686 - root - INFO - Log message 940
# INFO:root:Log message 941
# 2025-07-10 06:43:20,687 - root - INFO - Log message 941
# INFO:root:Log message 942
# 2025-07-10 06:43:20,688 - root - INFO - Log message 942
# INFO:root:Log message 943
# 2025-07-10 06:43:20,689 - root - INFO - Log message 943
# INFO:root:Log message 944
# 2025-07-10 06:43:20,689 - root - INFO - Log message 944
# INFO:root:Log message 945
# 2025-07-10 06:43:20,690 - root - INFO - Log message 945
# INFO:root:Log message 946
# 2025-07-10 06:43:20,691 - root - INFO - Log message 946
# INFO:root:Log message 947
# 2025-07-10 06:43:20,692 - root - INFO - Log message 947
# INFO:root:Log message 948
# 2025-07-10 06:43:20,693 - root - INFO - Log message 948
# INFO:root:Log message 949
# 2025-07-10 06:43:20,694 - root - INFO - Log message 949
# INFO:root:Log message 950
# 2025-07-10 06:43:20,695 - root - INFO - Log message 950
# INFO:root:Log message 951
# 2025-07-10 06:43:20,696 - root - INFO - Log message 951
# INFO:root:Log message 952
# 2025-07-10 06:43:20,697 - root - INFO - Log message 952
# INFO:root:Log message 953
# 2025-07-10 06:43:20,698 - root - INFO - Log message 953
# INFO:root:Log message 954
# 2025-07-10 06:43:20,699 - root - INFO - Log message 954
# INFO:root:Log message 955
# 2025-07-10 06:43:20,700 - root - INFO - Log message 955
# INFO:root:Log message 956
# 2025-07-10 06:43:20,701 - root - INFO - Log message 956
# INFO:root:Log message 957
# 2025-07-10 06:43:20,702 - root - INFO - Log message 957
# INFO:root:Log message 958
# 2025-07-10 06:43:20,703 - root - INFO - Log message 958
# INFO:root:Log message 959
# 2025-07-10 06:43:20,704 - root - INFO - Log message 959
# INFO:root:Log message 960
# 2025-07-10 06:43:20,705 - root - INFO - Log message 960
# INFO:root:Log message 961
# 2025-07-10 06:43:20,706 - root - INFO - Log message 961
# INFO:root:Log message 962
# 2025-07-10 06:43:20,707 - root - INFO - Log message 962
# INFO:root:Log message 963
# 2025-07-10 06:43:20,708 - root - INFO - Log message 963
# INFO:root:Log message 964
# 2025-07-10 06:43:20,709 - root - INFO - Log message 964
# INFO:root:Log message 965
# 2025-07-10 06:43:20,710 - root - INFO - Log message 965
# INFO:root:Log message 966
# 2025-07-10 06:43:20,711 - root - INFO - Log message 966
# INFO:root:Log message 967
# 2025-07-10 06:43:20,712 - root - INFO - Log message 967
# INFO:root:Log message 968
# 2025-07-10 06:43:20,713 - root - INFO - Log message 968
# INFO:root:Log message 969
# 2025-07-10 06:43:20,713 - root - INFO - Log message 969
# INFO:root:Log message 970
# 2025-07-10 06:43:20,714 - root - INFO - Log message 970
# INFO:root:Log message 971
# 2025-07-10 06:43:20,715 - root - INFO - Log message 971
# INFO:root:Log message 972
# 2025-07-10 06:43:20,716 - root - INFO - Log message 972
# INFO:root:Log message 973
# 2025-07-10 06:43:20,717 - root - INFO - Log message 973
# INFO:root:Log message 974
# 2025-07-10 06:43:20,718 - root - INFO - Log message 974
# INFO:root:Log message 975
# 2025-07-10 06:43:20,719 - root - INFO - Log message 975
# INFO:root:Log message 976
# 2025-07-10 06:43:20,720 - root - INFO - Log message 976
# INFO:root:Log message 977
# 2025-07-10 06:43:20,721 - root - INFO - Log message 977
# INFO:root:Log message 978
# 2025-07-10 06:43:20,722 - root - INFO - Log message 978
# INFO:root:Log message 979
# 2025-07-10 06:43:20,723 - root - INFO - Log message 979
# INFO:root:Log message 980
# 2025-07-10 06:43:20,724 - root - INFO - Log message 980
# INFO:root:Log message 981
# 2025-07-10 06:43:20,725 - root - INFO - Log message 981
# INFO:root:Log message 982
# 2025-07-10 06:43:20,726 - root - INFO - Log message 982
# INFO:root:Log message 983
# 2025-07-10 06:43:20,727 - root - INFO - Log message 983
# INFO:root:Log message 984
# 2025-07-10 06:43:20,728 - root - INFO - Log message 984
# INFO:root:Log message 985
# 2025-07-10 06:43:20,729 - root - INFO - Log message 985
# INFO:root:Log message 986
# 2025-07-10 06:43:20,731 - root - INFO - Log message 986
# INFO:root:Log message 987
# 2025-07-10 06:43:20,734 - root - INFO - Log message 987
# INFO:root:Log message 988
# 2025-07-10 06:43:20,735 - root - INFO - Log message 988
# INFO:root:Log message 989
# 2025-07-10 06:43:20,736 - root - INFO - Log message 989
# INFO:root:Log message 990
# 2025-07-10 06:43:20,740 - root - INFO - Log message 990
# INFO:root:Log message 991
# 2025-07-10 06:43:20,741 - root - INFO - Log message 991
# INFO:root:Log message 992
# 2025-07-10 06:43:20,744 - root - INFO - Log message 992
# INFO:root:Log message 993
# 2025-07-10 06:43:20,745 - root - INFO - Log message 993
# INFO:root:Log message 994
# 2025-07-10 06:43:20,746 - root - INFO - Log message 994
# INFO:root:Log message 995
# 2025-07-10 06:43:20,749 - root - INFO - Log message 995
# INFO:root:Log message 996
# 2025-07-10 06:43:20,750 - root - INFO - Log message 996
# INFO:root:Log message 997
# 2025-07-10 06:43:20,752 - root - INFO - Log message 997
# INFO:root:Log message 998
# 2025-07-10 06:43:20,753 - root - INFO - Log message 998
# INFO:root:Log message 999
# 2025-07-10 06:43:20,754 - root - INFO - Log message 999

# %%
# Q(19) Write a program that handles both IndexError and KeyError using a
# try-except block.

def handle_errors_example():
    # Example data structures
    my_list = [10, 20, 30]
    my_dict = {'a': 1, 'b': 2, 'c': 3}

    # Example 1: Handle IndexError for list access
    try:
        print("\nAttempting to access list elements:")
        print("First element:", my_list[0])
        print("Fourth element:", my_list[3])  # This will raise IndexError
    except IndexError as e:
        print(f"IndexError occurred: {e}")
        print("The list only has", len(my_list), "elements")

    # Example 2: Handle KeyError for dictionary access
    try:
        print("\nAttempting to access dictionary elements:")
        print("Value for 'a':", my_dict['a'])
        print("Value for 'd':", my_dict['d'])  # This will raise KeyError
    except KeyError as e:
        print(f"KeyError occurred: {e}")
        print("Available keys are:", list(my_dict.keys()))

    # Example 3: Handle both in one block
    try:
        print("\nCombined access attempts:")
        print("Fifth element:", my_list[4])
        print("Value for 'e':", my_dict['e'])
    except IndexError:
        print("List index out of range!")
    except KeyError:
        print("Dictionary key not found!")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    else:
        print("All accesses were successful!")
    finally:
        print("This cleanup code always runs")

if __name__ == "__main__":
    handle_errors_example()
# Out:
# Attempting to access list elements:
# First element: 10
# IndexError occurred: list index out of range
# The list only has 3 elements
#
# Attempting to access dictionary elements:
# Value for 'a': 1
# KeyError occurred: 'd'
# Available keys are: ['a', 'b', 'c']
#
# Combined access attempts:
# List index out of range!
# This cleanup code always runs

# %%
# Q(20) How would you open a file and read its contents using a context manager
# in Python?

# Using a context manager to read a file
with open('example.txt', 'r') as file:
    contents = file.read()
    print(contents)
# Out:
# First line
# Second line
# Third line

# %%
# Q(21) Write a Python program that reads a file and prints the number of
# occurrences of a specific word.

def count_word_occurrences(filename, target_word):
    """
    Counts occurrences of a specific word in a file.

    Args:
        filename (str): Path to the file to read
        target_word (str): Word to count occurrences of

    Returns:
        int: Number of occurrences
    """
    try:
        with open(filename, 'r', encoding='utf-8') as file:
            content = file.read()
            words = content.split()
            return words.count(target_word)
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found")
        return 0
    except Exception as e:
        print(f"An error occurred: {e}")
        return 0

if __name__ == "__main__":
    # Get user input
    filename = input("Enter the file path: ")
    word_to_count = input("Enter the word to count: ").strip()

    # Count occurrences
    count = count_word_occurrences(filename, word_to_count)

    # Print result
    print(f"The word '{word_to_count}' appears {count} times in the file.")
# Out:
# Enter the file path: example.txt
# Enter the word to count: line
# The word 'line' appears 3 times in the file.

# %%
# Q(22) How can you check if a file is empty before attempting to read its
# contents?

# Method 1: Check file size using os.path.getsize()
import os

def is_file_empty(file_path):
    """Check if file is empty by confirming its size is 0 bytes"""
    return os.path.getsize(file_path) == 0

# Usage
if not is_file_empty('example.txt'):
    with open('example.txt', 'r') as file:
        content = file.read()
        print(content)
else:
    print("File is empty")
# Out:
# First line
# Second line
# Third line

# %%
# Method 2: Read first character (most efficient for large files)

def is_file_empty(file_path):
    """Check if file is empty by reading first character"""
    with open(file_path, 'r') as file:
        first_char = file.read(1)
        return first_char == ''  # True means empty

# Usage
if not is_file_empty('example.txt'):
    with open('example.txt', 'r') as file:
        print(file.read())
else:
    print("File is empty")
# Out:
# First line
# Second line
# Third line

# %%
# Method 3: Using file.tell() after seeking to end

def is_file_empty(file_path):
    """Check if file is empty by seeking to end"""
    with open(file_path, 'r') as file:
        file.seek(0, 2)  # Seek to end
        return file.tell() == 0  # True if position is 0 (empty)

# Usage
if not is_file_empty('example.txt'):
    with open('example.txt', 'r') as file:
        print(file.read())
# Out:
# First line
# Second line
# Third line

# %%
# Method 4: Using pathlib (Python 3.4+)

from pathlib import Path

def is_file_empty(file_path):
    """Check if file is empty using pathlib"""
    return Path(file_path).stat().st_size == 0

# Usage
if not is_file_empty('example.txt'):
    print(Path('example.txt').read_text())
# Out:
# First line
# Second line
# Third line

# %%
# Q(23) Write a Python program that writes to a log file when an error occurs
# during file handling.

import logging
from datetime import datetime

def configure_logging(log_file='file_errors.log'):
    """Set up logging configuration"""
    logging.basicConfig(
        filename=log_file,
        level=logging.ERROR,
        format='%(asctime)s - %(levelname)s - %(message)s',
        datefmt='%Y-%m-%d %H:%M:%S'
    )

def safe_file_operation(file_path, operation='read', content=None):
    """
    Perform file operations with error handling and logging

    Args:
        file_path (str): Path to the file
        operation (str): 'read' or 'write'
        content (str): Content to write (for write operations)
    """
    try:
        if operation == 'read':
            with open(file_path, 'r') as file:
                return file.read()
        elif operation == 'write':
            with open(file_path, 'w') as file:
                file.write(content)
            return True
        else:
            raise ValueError(f"Invalid operation: {operation}")

    except FileNotFoundError as e:
        logging.error(f"File not found: {file_path} - {str(e)}")
        print(f"Error: File {file_path} does not exist")
    except PermissionError as e:
        logging.error(f"Permission denied: {file_path} - {str(e)}")
        print(f"Error: Permission denied for {file_path}")
    except IOError as e:
        logging.error(f"I/O error: {file_path} - {str(e)}")
        print(f"Error: Could not complete operation on {file_path}")
    except Exception as e:
        logging.error(f"Unexpected error: {file_path} - {str(e)}", exc_info=True)
        print(f"An unexpected error occurred: {str(e)}")
    return False

if __name__ == "__main__":
    # Configure logging
    configure_logging()

    # Example usage
    print("=== File Reading Example ===")
    result = safe_file_operation('nonexistent.txt', 'read')
    if result:
        print("File content:", result)

    print("\n=== File Writing Example ===")
    if safe_file_operation('test.txt', 'write', "Hello, World!"):
        print("File written successfully")

    print("\nCheck 'file_errors.log' for any error details")
# Out:
# ERROR:root:File not found: nonexistent.txt - [Errno 2] No such file or directory: 'nonexistent.txt'
# 2025-07-10 06:55:13,809 - root - ERROR - File not found: nonexistent.txt - [Errno 2] No such file or directory: 'nonexistent.txt'
# === File Reading Example ===
# Error: File nonexistent.txt does not exist
#
# === File Writing Example ===
# File written successfully
#
# Check 'file_errors.log' for any error details
